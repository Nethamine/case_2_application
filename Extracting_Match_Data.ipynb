# %% [markdown]
# # **Extracting League of Legends Match Data using Riot API**

# %% [markdown]
# #### **What motivated me to create this guide?**
#
# I play League since season 4 and I´ve always been a fan of the game. Recently I have started studying Data Science and the analyst sector in esports, manly in LOL. And one day when I was trying to figure out a good project to my portifolio I came acroos a idea of using league of legends match data to make exploratory analysis, data visualization and ML.
#
# So why not?
#
# Since then, I have been looking where could I find LOL match data to use in my project. I even found some places with data sources available, but I decided to "create" my own data source, to my project be even more unique. After I decided this, I started studying about RIOT API to understand how could I use it to create my DataFrame. When I was able to figure out how I could do this using python + RIOT API, I immediately though about creating this guide to help others that might be in the same situation that I was.

# %% [markdown]
# #### **Do I need to know python?**
#
# This guide does not require you to know all about python. But it is recommended that if you do not know or if you know just a little bit, you look for some free python tutorials on the internet and Googling certain areas where you are not understanding what is going on.
#
# If you have any questions, feel free to send me a message on linkedin.

# %% [markdown]
# ### **Importing Libraries**
#
# We will need 3 libraries thourghout this guide:
# - Request: Managing all our API requests
# - Pandas: Manipulating Data
# - Time: Handle if the riot API rate limite

# %%
import requests
import pandas as pd
import time
from warnings import simplefilter
simplefilter(action="ignore", category=pd.errors.PerformanceWarning)

# %% [markdown]
# ### **Getting your API Key**
#
# Log in with your [Riot Account](https://developer.riotgames.com/) and accept the terms of service. At the bottom, click "I'm not a Robot" and regenerate your API key.

# %% [markdown]
# Copy the API key below

# %%
api_key = 'RGAPI-16114d75-2b98-491c-ac68-e87cfbb9909f'

# %% [markdown]
# ### **Part I: [LEAGUE-V4 Endpoint](https://developer.riotgames.com/apis#league-v4)**
#
# In this part we will use the League - V4 Endpoint to get the summoner information from players with elo greater than master

# %% [markdown]
# First lets do our first API Call. [Click here](https:   //developer.riotgames.com/apis#league-v4) to go to the League-V4 ENDPOINT.
#
# Now click on the ENDPOINT "/lol/league/v4/challengerleagues/by-queue/{queue}", scroll to the bottom of the page and select RANKED_SOLO_5x5. Then, click "EXECUTE REQUEST".
#
# If all is correct you should see a 200 response code. And bellow it, on the Response Body, you should see, in this case, information about challangers players.
#
# Now go back to the beggining where you can see the request url. This is the url we are going to use to make the resquest, so copy and paste it in the code bellow.
#
#
# **IMPORTANT:** When dealing with APIs, we need to add "?" in the end of the ulr and declare the parameter name and value as we did bellow.

# %%
api_ulr = 'https://br1.api.riotgames.com/lol/league/v4/challengerleagues/by-queue/RANKED_SOLO_5x5' + '?api_key='+ api_key

resp = requests.get(api_ulr)
resp
# Out:
# <Response [200]>

# %% [markdown]
# We are getting a 200 response code, which means sucessfull. But to see the data from this request we need to use the json method.

# %%
api_ulr = 'https://br1.api.riotgames.com/lol/league/v4/challengerleagues/by-queue/RANKED_SOLO_5x5' + '?api_key='+ api_key

resp = requests.get(api_ulr)
resp.json()
# Out:
# {'tier': 'CHALLENGER',
#  'leagueId': 'c9c33ae0-81ab-3e14-bbec-00b1d071e980',
#  'queue': 'RANKED_SOLO_5x5',
#  'name': "Trundle's Tyrants",
#  'entries': [{'puuid': '5UKAB3BdAjfwztS7ZkHQPd5F78ioiLIDGawV572j663hp1v3k_8-NcyHBxH1S0a5Oj_6Qq00VCSURg',
#    'leaguePoints': 2123,
#    'rank': 'I',
#    'wins': 200,
#    'losses': 127,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'puuid': 'RSv3jqMfNnzJdOQtFj1EJQD6cb33vNTkChk80eqjQxIIKZSza7fy5nnrVlsroMZCaqcj4cLn-7otbA',
#    'leaguePoints': 2110,
#    'rank': 'I',
#    'wins': 210,
#    'losses': 84,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'BuSj5sCliNI8TMAEOj6YEQ8qCaANtfjR1ggshJrYEtknF6jgouk0Sopi2wf89hbYA9kMpTkZxUUiHA',
#    'leaguePoints': 2000,
#    'rank': 'I',
#    'wins': 251,
#    'losses': 144,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'puuid': '27uMJ1ScPoerO8mnOHwAdb40__AZmUZgCuU7cWzcgseMUghYzYW-ORvexyHjAeoPLsUX88kEsw9pzw',
#    'leaguePoints': 1967,
#    'rank': 'I',
#    'wins': 202,
#    'losses': 76,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'By-BwlILMKrhWd6etoNg9xBdh9r1MNAaZtunZqzKJWTJ2U8TNMUEr7Yov7uErgjo_AS_GPapUm-Vxw',
#    'leaguePoints': 1916,
#    'rank': 'I',
#    'wins': 127,
#    'losses': 68,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'rq0iCYnzfTgF5itI472beFCjRP_f5M22OowpJUpvXYgSINFOQlbwEC43_hY2MFg_Z3i3_NsWWHLtjg',
#    'leaguePoints': 1855,
#    'rank': 'I',
#    'wins': 208,
#    'losses': 139,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'puuid': 'YkTi5xik8kQp8N0wEWQMMkm0gDECq1dwgz_VXRETHvLHALCT2D1Ou3g_yxJkApQdLMs7HaPLjdiw6A',
#    'leaguePoints': 1846,
#    'rank': 'I',
#    'wins': 129,
#    'losses': 70,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': '44dHU0Pa4LAtTjCtg-7atvW1a1Aus6qPDr-lWRONuPR5DwJKQNVfNv_d1y4XDlWTh2ZS6XKJtNqJWg',
#    'leaguePoints': 1823,
#    'rank': 'I',
#    'wins': 195,
#    'losses': 127,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'DAuoX4AO20IGfNaq0g7mPKKremTChU6K5o0XlP5vuhtez5P55rpYTAE5vWYkFwDW6ymLoW-0VtYrJQ',
#    'leaguePoints': 1823,
#    'rank': 'I',
#    'wins': 170,
#    'losses': 104,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'SZUaH41CZbmZUuhdG9BWuqDMQK3rrGctVe4OK8JlRopLl3JIM4iDHyrcWWff_MiIk_rERLRUqc3pwg',
#    'leaguePoints': 1816,
#    'rank': 'I',
#    'wins': 232,
#    'losses': 149,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'R3_dve0GhEF7DVnafrizMG2WGBwcvg0sQJSjKNM2iMFaWNF255aY7eGyFXEDXkR7RrKAmG2Buy-xyQ',
#    'leaguePoints': 1783,
#    'rank': 'I',
#    'wins': 106,
#    'losses': 45,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'Py7vQMc-nU3qj23MWx-p8vsun9gbVKGRXRMjdv8eSdesz1LvB50Ra8Oo1-G0WXbxSmzX3DujxnUQqg',
#    'leaguePoints': 1769,
#    'rank': 'I',
#    'wins': 230,
#    'losses': 133,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'PDrjb8JwcFHCeOEPj0Stb-FRFRYrzZQzjLdGOUQYfokV18i8dlKdgT18Vx4ZG8Ep60uzO35g_YEj5g',
#    'leaguePoints': 1750,
#    'rank': 'I',
#    'wins': 141,
#    'losses': 98,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'puuid': 'D10B-FyacCQoFLfM46RiRVAHapH96-vFUFmTUGIbdbbSoFpGJ-41hCllk131G0uwuC0cLKM3Mex5LA',
#    'leaguePoints': 1747,
#    'rank': 'I',
#    'wins': 87,
#    'losses': 26,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'ACWtsgRYqXnrp4SlkgiJgmbEPHtGrxT3ckZZEWDpuwVSC3zOCJeuIEvkVhngFgJ5xOT67kZyOptrdw',
#    'leaguePoints': 1688,
#    'rank': 'I',
#    'wins': 283,
#    'losses': 228,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': '53F4ojfxhzgg2JW2U9Du5Byw_a4dr2NRzUdHjUMXvAbXqlmxEYwVwda50PXAtbiVVJCKOWiYeUEF4g',
#    'leaguePoints': 1670,
#    'rank': 'I',
#    'wins': 169,
#    'losses': 108,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'puuid': 'UthokLVweZeBnFFQP5fiagbzH2ryP3jW8-dTdztjtPVTOiMgzKJwrFVigOQpk_OQ7tQEnSFwkB0LoQ',
#    'leaguePoints': 1665,
#    'rank': 'I',
#    'wins': 201,
#    'losses': 143,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'puuid': '1TR9typj2wI2hiMEwxNlYZB2xGiDIaO2R-FupaFUOKktYngNOkWL0FZSHJ7lMx5Vogk-Qebi9qQfYw',
#    'leaguePoints': 1653,
#    'rank': 'I',
#    'wins': 182,
#    'losses': 134,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'L7rG9jcktBxNZqqUimchm4KmCTQ5u1ZAR606JRc7pOSsIchDEVXHv1wcxyiAsObl_uc5MqQL985pGw',
#    'leaguePoints': 1647,
#    'rank': 'I',
#    'wins': 171,
#    'losses': 109,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'VsDAa6jRol0uRmcc3RhIMBaXYmNs_AKbaf5XYcZ5Jzd0rcUgzsFtrUJ6twZDxYTzsv_VewdbNl-NrA',
#    'leaguePoints': 1611,
#    'rank': 'I',
#    'wins': 154,
#    'losses': 113,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'puuid': 'XgoNG8USgbF0R1PxsyR0RBGC5XsaEyAAgB_WUhUmQCTF5vK5UqDPKSeXv9Sbpo8qeNV4wQuWTa9TUw',
#    'leaguePoints': 1599,
#    'rank': 'I',
#    'wins': 130,
#    'losses': 78,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': '2Xox_92OYzRRmJGVyMxidZwF4hh61mBUfp3sbU47yAxcbvYDwuJ_qfRlALEvCZWSO0qAMihzhle6ZQ',
#    'leaguePoints': 1583,
#    'rank': 'I',
#    'wins': 212,
#    'losses': 142,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'NLYAL1RSw7ql_j2eYx0-7KVWSUz86Hy6pHo6wNGTzGnMZ5rvOu2pMXno6a5jn3fEEj9Kh_2PTmiXNw',
#    'leaguePoints': 1570,
#    'rank': 'I',
#    'wins': 114,
#    'losses': 64,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': '__layBs7vjIcxV54c4SgJxRNT7-njkK-KuuUvOZLKx_xgmBs--GY6ZdBJpq3Ue5C9FhAM27EZ3h2mw',
#    'leaguePoints': 1567,
#    'rank': 'I',
#    'wins': 277,
#    'losses': 192,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': '8yfB3oJvXq_hCaZGO6TtHgcU-X_6obKJJ9CuH_sg9L3N8Y4GSt-EO7_7SVDzFwuReEOXoWfIY8Emzw',
#    'leaguePoints': 1567,
#    'rank': 'I',
#    'wins': 134,
#    'losses': 83,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'NMxrfz2StKNLhYqR7Evj8fLtTJ0TWzTetgOgJmpJZ3se9yVDgEyWPQ33Yu_23OujbF05jl5DqA1tYA',
#    'leaguePoints': 1545,
#    'rank': 'I',
#    'wins': 256,
#    'losses': 197,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': '-TmFVmeQCk9rwlg1cV6U4iw43ZYC4JZZbeAKjWGtLaKJnjggg6LytdtIKwsiOp-HEx6JwaUjx93DLA',
#    'leaguePoints': 1518,
#    'rank': 'I',
#    'wins': 137,
#    'losses': 95,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'puuid': '8Hv0X4oWPAAk0xfhr2xVmVpajycIqM3CVAj3cn6CBRHwEgBf6mx-PybyJ-TSkn6BcmXBIq-uIXittg',
#    'leaguePoints': 1509,
#    'rank': 'I',
#    'wins': 85,
#    'losses': 46,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'puuid': 'XGLGRHGKx61-Nu6wsRjRPPTDli03EdfL_82D61ic8t80QSsgbrXowgA_POCJHFFy5CnwNEmRBHx3UQ',
#    'leaguePoints': 1508,
#    'rank': 'I',
#    'wins': 181,
#    'losses': 108,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'puuid': 'yCR_giBkxY7nz9zoF9P6hllfeLCkjh2r_I6xVzQUtTRiv2-F_G2UjpqGSY3OzCbg3lHjKEiiIWsEng',
#    'leaguePoints': 1500,
#    'rank': 'I',
#    'wins': 97,
#    'losses': 27,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'puuid': 'wQjJKcqfTbodhvXA0JKihgiM_N0ms0vjk6KZBlELk4Bqt6LkW3bO7U0A_zdSLgNhcL5Ih8eTleQOKg',
#    'leaguePoints': 1487,
#    'rank': 'I',
#    'wins': 325,
#    'losses': 258,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': '6JY7vYH56v7KHavmSLeJ7v10qHwBgzeoFtMn0y6BMD2haCPclq8nWbKdL8J_X4YBtadSjlG_nJ_DIQ',
#    'leaguePoints': 1487,
#    'rank': 'I',
#    'wins': 101,
#    'losses': 64,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'puuid': 'uoiOzG_EJ3sfbVAzOEb8_YfcY7szcNYSmxaLNzUpP5PveeJA10myRs5DhIBbq-B7UDVYNPFP-5anbg',
#    'leaguePoints': 1486,
#    'rank': 'I',
#    'wins': 142,
#    'losses': 82,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'g4x6NGXaltaZKaQmBTg2yMj9NlUzMoA3ZAWMYxkrbKIk7nZopRjJSnSybJ26iGBwVIjXRqkOyvqQ-w',
#    'leaguePoints': 1478,
#    'rank': 'I',
#    'wins': 171,
#    'losses': 128,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'qojVmF-FZJBy9yjt7cM3tJ36D5rn7A8RpklqFWTeu9Ipl_3AQVZr-Mwu6hIxEYLxXgIWXXTo7cZzow',
#    'leaguePoints': 1475,
#    'rank': 'I',
#    'wins': 132,
#    'losses': 77,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'hkWnzNLRNVhoxtBjrEg8XYQFbT40BQe0877fdOnClp0U90ovynmPOuBbFk2BMbtn6yOLiXBR8pvN9Q',
#    'leaguePoints': 1466,
#    'rank': 'I',
#    'wins': 184,
#    'losses': 134,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'kf47Rccw3lufXZrerKJsd-iael8xSNuAZ5SjT6-DI96qsoKpZdih1wCP1jTiWzyrHu8qjrYoWPvZUQ',
#    'leaguePoints': 1457,
#    'rank': 'I',
#    'wins': 262,
#    'losses': 212,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': '7NGUotBKtuz60EsTRphCywAyzwW8M9_baPdvv_kSirqQzAwq9J0-uF4ON9o8PG1K5-S6OJWSPBpXMA',
#    'leaguePoints': 1449,
#    'rank': 'I',
#    'wins': 123,
#    'losses': 98,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'ELcSjSqOLZS1l3YeKd208dpavPtHvZkphGCGcACykqdrTo1TxEntaCJooZ-3deCxKSxMmiGv-fA93g',
#    'leaguePoints': 1447,
#    'rank': 'I',
#    'wins': 192,
#    'losses': 127,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'puuid': 'Tif3xJ_0XR5nVWLTRCpArwzUaqlVEf5oh0b9xW-xwBZAU4TlaU_hCW6xCyWw3IF9KngCcEZkfhwZbQ',
#    'leaguePoints': 1446,
#    'rank': 'I',
#    'wins': 140,
#    'losses': 67,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'puuid': 'QhWuYMxKn49LaC8gqkzomCfNYLBq2AA1LAUsAhXtpTvMrs9reClUXXhWXMqWPkb5WYssLmBE8olPog',
#    'leaguePoints': 1416,
#    'rank': 'I',
#    'wins': 153,
#    'losses': 112,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'mwiZ1VbvW1mgfZ28DqJGfmwcG8SFwClaIB1cpW9wRkt5p7sNqIXfzG88o0HOFSxh2kdNGrOGZDXVrQ',
#    'leaguePoints': 1415,
#    'rank': 'I',
#    'wins': 164,
#    'losses': 121,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'rmEIM_1RsnyF3ShAJ64ZUz_iJ0VxXM9PM__x17ayoE00EoNcRkkthXnZSSZT0yF5lP15qwGp1tioMQ',
#    'leaguePoints': 1399,
#    'rank': 'I',
#    'wins': 147,
#    'losses': 116,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'WCKvQQ2MWMm97L8HEee8mnwGcOZ43IAVm7VwQQ6JdNZfP3tH8sqN0KhLeBUr4kGQZh388dSoHopQrQ',
#    'leaguePoints': 1399,
#    'rank': 'I',
#    'wins': 124,
#    'losses': 67,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'c22wkOk_yw2SMRt-X2ZewqdgniPCcAgHs0DbZWXm5WfKzRDR1JNgPN6wW7W4mDeaHtCelsbgV6-0nw',
#    'leaguePoints': 1392,
#    'rank': 'I',
#    'wins': 114,
#    'losses': 70,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'rIv0DtZqnHS94COQINeQ825TrKXxM5Fln0X9lK0-zHyeoaygczAYyY5IwMdGi1p27VDvrp6QUT1SUw',
#    'leaguePoints': 1391,
#    'rank': 'I',
#    'wins': 255,
#    'losses': 189,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'FCY2OSRaebNB1dR68P7Qr0L5AOxBP4DzzA_rK-TK1E2-U4yByLu_E-e2Mu3uNH-F2N4wb9AbUQa0Ig',
#    'leaguePoints': 1391,
#    'rank': 'I',
#    'wins': 110,
#    'losses': 80,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'puuid': 'jfpU24MyNszKbIke8XHDIuvuvBVcrlGIFsgT_HXV2wIpRNPWV2lAtPmAO9eLyHMkp0AzLJ9sRwdH1A',
#    'leaguePoints': 1382,
#    'rank': 'I',
#    'wins': 153,
#    'losses': 106,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': '2ZBz2l2NHnjSxif1eNi6E8RzfyUzYEbE32tzPmqwYaIRE8GjI1gW_cioNsvKCyVGz_w6fCHIPx3ojg',
#    'leaguePoints': 1379,
#    'rank': 'I',
#    'wins': 97,
#    'losses': 54,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'NhvS-HZYAEMGEn4NBctyQYrYznUlZ52pLYGtcAjyULWoXfu8Fc3S2dMzBJoTzR1r_ZodShJ-QwvVkQ',
#    'leaguePoints': 1375,
#    'rank': 'I',
#    'wins': 180,
#    'losses': 104,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'puuid': 'wCnhc0UTbJf2wERbeVqxT42AZmVWxOHzG-bKaCAeLHVl4hMehwivQHz76iPjUg519Dq8CUF0yKFMxA',
#    'leaguePoints': 1375,
#    'rank': 'I',
#    'wins': 147,
#    'losses': 117,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'qAN-1zZhnioI7mZzWg-zNEmNhY92E6rtvJQDHV7aStb4m7ggkWxDVg9oU7ndAs89H3nW93iU7Olusg',
#    'leaguePoints': 1370,
#    'rank': 'I',
#    'wins': 152,
#    'losses': 130,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'TO-_z-wMjxCMa08OVcLrNyJEv2FbdgmyFlj3E_KyleZDPgdNp2TvTAeo1jlykEzMUdbPO7_a0rSolw',
#    'leaguePoints': 1369,
#    'rank': 'I',
#    'wins': 194,
#    'losses': 128,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'Yx-S5fPNOwbJeYCcotZnCUzL6mbzhd03c4I1G9dgs_wTYuJmd0mWG2sg5xn8RkZNXQA64d6eKsmPaw',
#    'leaguePoints': 1362,
#    'rank': 'I',
#    'wins': 134,
#    'losses': 69,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'rDiXkGMT7JVsnfRtApVgo2Dd2AKhym-D8Na-BA7NV1uJLMAgHNEwS16Lz_EgzRvJz9B18RdFT6n9Qg',
#    'leaguePoints': 1361,
#    'rank': 'I',
#    'wins': 127,
#    'losses': 104,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'kgx4WXnq-dTIcY9p2figFu575UHtot7GdLyiEBdGrji2Ox-k4P80I6_mrA2vr5E5makgFI2KpJSJvA',
#    'leaguePoints': 1360,
#    'rank': 'I',
#    'wins': 131,
#    'losses': 94,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': '0nrz9yogoBnstpsLKhopyrsfiLWL51Yg6UXmPUYFa7v4mvtifzcaAfGKs05eQXYoPd_mPQuOGTB8Bg',
#    'leaguePoints': 1359,
#    'rank': 'I',
#    'wins': 168,
#    'losses': 119,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'p6NoYRim5zpRlrSRW7nDra1jvMkIG7GN5JhKHyENcFZGKrKUYLjQThU1caJw--kddhKo0YJurta6dg',
#    'leaguePoints': 1349,
#    'rank': 'I',
#    'wins': 183,
#    'losses': 128,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'K_FtQOU2qyEkzRKUkHrbHv6MxpQ2a6uu4YxMs6FqvCj5VWqewMYk8NqJcTmp5CHiyTxK5JFruMOj8g',
#    'leaguePoints': 1346,
#    'rank': 'I',
#    'wins': 117,
#    'losses': 76,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'Y43wTY23QS9qK1TimXnvruZYrDx2Av0GRNtnyk3s1UblshqaesKm13Rj2EWeRRU_-mXX47LfT3DOdw',
#    'leaguePoints': 1341,
#    'rank': 'I',
#    'wins': 282,
#    'losses': 212,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'puuid': 'lN3NHMmRP0Zu3Jh6uPgwGVOElV8rRNWMEj00h_BP39ISIhb38-VHyXpbPYRPqtN0WaSc8Lgylk_xkg',
#    'leaguePoints': 1327,
#    'rank': 'I',
#    'wins': 131,
#    'losses': 93,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'n8UKiEiS8lfXbXvcGVgEORwtUluOLVFi6egIF-paW5KgYZwdtznAXUOwrjXRy_ZaVGyxsyxdNGLxRQ',
#    'leaguePoints': 1315,
#    'rank': 'I',
#    'wins': 86,
#    'losses': 59,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'UliX4aXCq78Ov4q2l2rEU-9SWqXfXRyvHNY4RErUcmjOlKSr1iYDR_pUV_e6KTWTnKpb1s3tDC_IHQ',
#    'leaguePoints': 1302,
#    'rank': 'I',
#    'wins': 152,
#    'losses': 118,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'puuid': '1j3vO-86EWnoLioocU_E1I1wM6oJGA4gD_R_BB4FHevFNVIyscoa4xxzJbcvI3ZSE65qC7HiQvpojQ',
#    'leaguePoints': 1295,
#    'rank': 'I',
#    'wins': 117,
#    'losses': 69,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'puuid': 'FtDpZQbE_mLWDLyS6KGG9wx6yoZdNhjhA7t4LCzzqxo8gAjCeOrizonVm1em3MKkupTGHF6ApZgA2w',
#    'leaguePoints': 1293,
#    'rank': 'I',
#    'wins': 145,
#    'losses': 78,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': '13xgFSw5oSQ3pfn1OUz4QlSNUCW6lxtp7IzIbr2tVdiCJWXkVu2X7svAqDR8PmNNtN4HmjLdspSWSA',
#    'leaguePoints': 1290,
#    'rank': 'I',
#    'wins': 130,
#    'losses': 103,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'RuOzeSccdrnnguKytetjT9QYADCtOmox4lYk6v4of4mBl0bZ7IoJdr-qrpF69_jxiU15eQlt7xuA8w',
#    'leaguePoints': 1288,
#    'rank': 'I',
#    'wins': 205,
#    'losses': 144,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'Kn66r060LDhH67UVqJk5tcIYiGzR1nEUFBgBEnbB2ihwNyO3WNOZH1ZydERKnTNpLo0w7nqPsl5i3g',
#    'leaguePoints': 1285,
#    'rank': 'I',
#    'wins': 119,
#    'losses': 81,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'pQW28b3-maYLqeV5H4R-0_Qi2Fsm0x-A6-Ll-6TGJzgW2pJkr3RT2lKscH-2kfmUHkU5SBdhInYOzQ',
#    'leaguePoints': 1285,
#    'rank': 'I',
#    'wins': 97,
#    'losses': 37,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'g75lWCz9AF4MfmxoFnVTC9ZfwIjQxAPmAfFp_s-7rztsYEOExnPm_zphPPnzxiM0nbasKFr6OS1iew',
#    'leaguePoints': 1277,
#    'rank': 'I',
#    'wins': 183,
#    'losses': 107,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'puuid': 'QEYIhcu5y5jrH-JHsv5O_OztsKYQhj9QkeyyuBpDw-CN8fYLpR8_R4yg9PuTOJ7kyP2ex5U1CkBo1Q',
#    'leaguePoints': 1275,
#    'rank': 'I',
#    'wins': 102,
#    'losses': 60,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': '6Hr2nCc9R5yiapIyvol4R-W8DZJVqdCIs5qTh-tQCuc4P7KYEjOulq8faD_3tClNYVw873dZb47fcA',
#    'leaguePoints': 1274,
#    'rank': 'I',
#    'wins': 198,
#    'losses': 143,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'X4GKKiZbmajiLh2spKLx7jis28Fwn7s90Gj7d7b_MDQatqpb09bX_ATQA0cquVN2o8V2H0sByPhmZA',
#    'leaguePoints': 1273,
#    'rank': 'I',
#    'wins': 171,
#    'losses': 133,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'dRluI1bOmtKsUUW4ubgss85EK6p7dL5CPH-ID46Ik5tssJhmezNkcK1TqouZ142NoRhhu7xFgj659g',
#    'leaguePoints': 1272,
#    'rank': 'I',
#    'wins': 178,
#    'losses': 121,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'puuid': 'OPpx7VrlC_wGGBlXGgWPZGwlyIyEaJDfpEnQcoW1gjFyPVpM8t3ozrzzzuvqYjDVYNerJmvDKikXSw',
#    'leaguePoints': 1269,
#    'rank': 'I',
#    'wins': 168,
#    'losses': 108,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'IvF_XvOOju2v8iGB2d_vm33okjvCU2l7AA-2C4cOBS9oB_xL6JXBWmNk_-utO8I1wcyLrIira7SY8Q',
#    'leaguePoints': 1257,
#    'rank': 'I',
#    'wins': 113,
#    'losses': 50,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'lf-raZRdzhVmP9RFOK3YY_rNPvhyG3J4kWswI_ZCdHw0R0ChCmnjD1jfKIMlUf8hF7dgEE1IEJZakw',
#    'leaguePoints': 1256,
#    'rank': 'I',
#    'wins': 123,
#    'losses': 92,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'xe7rMApdZnKVEV6VUTNxRN7fQYveyVvIyzBO-wc3RdAJmVXNpjYW2Ya1Ur_2TTO9kW424iGs00E5FA',
#    'leaguePoints': 1255,
#    'rank': 'I',
#    'wins': 109,
#    'losses': 70,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'mPgK2C1gudmcXYXG9BhTusHKgHzEfr9HxoQJWUnsblp4bOBSJrHwAYsMh9zRud2laSzVk6hIuuLuhQ',
#    'leaguePoints': 1253,
#    'rank': 'I',
#    'wins': 156,
#    'losses': 127,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'puuid': 'Wklys_SeYI0eNItKERHCIoWXINQuf1cfG4eG4yenj2CjtF9b9HR9mKtBW9Y29QWAKCsfSTVr0DDY4A',
#    'leaguePoints': 1252,
#    'rank': 'I',
#    'wins': 154,
#    'losses': 126,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': '8gz5bcXtC2KuYWKsb1m0MdnOBmvS5b3aOaRndtbhjclIc-zaGmUmhyP-AmKLXXtgdZGnb6fcK1P0kw',
#    'leaguePoints': 1251,
#    'rank': 'I',
#    'wins': 106,
#    'losses': 83,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'puuid': 'Ytlxf36l-Fxj6yZ46YY-GWbgQsrltqZ-sGsrYLKnX2vjVU4kGjzmiHNcZgw-zceZUy8GyzhJQODT3Q',
#    'leaguePoints': 1245,
#    'rank': 'I',
#    'wins': 174,
#    'losses': 121,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'gxEksRwxE_NGHJ4QezIROIb-JmCMucMxuUa70zOlB3kPj3rxFr6PFOqRfajnVM2eAR1YGjrn75Cs3Q',
#    'leaguePoints': 1242,
#    'rank': 'I',
#    'wins': 140,
#    'losses': 108,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'MAUOYgxlGe0fk3UTPqI5fSGuzRq_-FicAlmVh0DFlWyLRMIKvNHvp8Hjj42eBUU_RYRKWggotSwPoQ',
#    'leaguePoints': 1238,
#    'rank': 'I',
#    'wins': 143,
#    'losses': 114,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'puuid': '4sN9-6LQosYxJUwLWmoNhRtzw4rdZuFsn0vg13Gkwz9wPzZas1Cag7C-gxTJmhCpVYhJZX5BKAuNjg',
#    'leaguePoints': 1236,
#    'rank': 'I',
#    'wins': 114,
#    'losses': 65,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'puuid': '_L3jG4Azuy4oi_Viwr5Kcohu_X7qTcD0Uqcp93VndPdBcCQQJrHAJhbzFWiqLbPDrkBEpCKz4MfuxQ',
#    'leaguePoints': 1231,
#    'rank': 'I',
#    'wins': 170,
#    'losses': 133,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'ExKvds6kLut3EuYbJ1QNeLsiahcyWq_w27FTcl2NK4F4d0NcOXghyTYPzqRK2JNR4DlFoA6u2OSvDg',
#    'leaguePoints': 1231,
#    'rank': 'I',
#    'wins': 152,
#    'losses': 120,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'khTi-n7slhAAH8IZP_XHNBYu3Jdsy-RjmyJxMOsH53-6IantqbDqA8UVutI2HL49zUTVUPrhVoRM7Q',
#    'leaguePoints': 1230,
#    'rank': 'I',
#    'wins': 107,
#    'losses': 61,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'wyOjHc5Z2d1eFn6F0jb-YLjLy5TFC8o13Cxkg0x-btCudwV1Vj3xs3sLqPAFONBJQw5odcHu4bMyjw',
#    'leaguePoints': 1224,
#    'rank': 'I',
#    'wins': 142,
#    'losses': 106,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'cJDU9sNJOIZxsjlErRV0j7eZowTNJ8pB6vZwvtYuP8CICBQv9o8gJdHDo0nHRaAr1GTRH_S22LdoJQ',
#    'leaguePoints': 1223,
#    'rank': 'I',
#    'wins': 123,
#    'losses': 96,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'puuid': 'HDjvqai0fVgXD5xBYc7JpBqKbhckVQB9hS0Q1N1WoGkifyP-V3EPKrYb3eS2_bRgzvFArChB-3uCaw',
#    'leaguePoints': 1220,
#    'rank': 'I',
#    'wins': 127,
#    'losses': 108,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'So-Kg76LQRfpQnZ_nHGa9yWXPM97wLjTnQerqvQ7XLtDQjhSiNTVobYnn0Y9iT17ZQhd-Q2_VrbxfA',
#    'leaguePoints': 1214,
#    'rank': 'I',
#    'wins': 102,
#    'losses': 77,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'IQpS2F-Vvyx1SD4oNAe4Ogc2mNYQv8SDzxhePc-iMVEwARC_H0tpoxhYBW8Oruo1Ix4-CJsivvX0dg',
#    'leaguePoints': 1213,
#    'rank': 'I',
#    'wins': 139,
#    'losses': 95,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'puuid': '9AycsmqLW5Ps4xF2TUrthxoDZNrCyvoo0HMIprPa8XRcMiurSPqTnLVnOj5aTRQTDmBTGVoTdBqjkg',
#    'leaguePoints': 1212,
#    'rank': 'I',
#    'wins': 151,
#    'losses': 129,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'pwZ9Z3Vr3_oKXHVzhh6VdZY6jAnmuh_ZutJ1s253JD4syjdejM2Z37R9f6gP5iRixu9nadMr7TBCxQ',
#    'leaguePoints': 1210,
#    'rank': 'I',
#    'wins': 131,
#    'losses': 99,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'X0_WEmdrxlqz7jzortV8RUPXOgn4zdyg-0wkP8N6SafrJ8EX6VsiXvdBRze3kHOGIhW8aXKT_qr_0Q',
#    'leaguePoints': 1204,
#    'rank': 'I',
#    'wins': 213,
#    'losses': 171,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'puuid': '8_Sli2IpMSlkcNbcr8bmjb6AIVgXn4Z3pX5BYA824BEGTLXIWazUbzYZE7vSEx1SphGAUWUHLsVmOA',
#    'leaguePoints': 1204,
#    'rank': 'I',
#    'wins': 164,
#    'losses': 140,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'IlrWeVIi_MLre7A8QocAzkNX0lZDRGWNqXCV6bzstpeUh56jSWkgEqFUqaCavpewvUnLJSeFzBAA9Q',
#    'leaguePoints': 1183,
#    'rank': 'I',
#    'wins': 112,
#    'losses': 71,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': '5tSgBh362mD-330cqUoFVODrUOcscA_F6ILiNbvFUp9PMLZWoyvK9Zb0BTy1lDW3ztZtv8RKvCaQIQ',
#    'leaguePoints': 1182,
#    'rank': 'I',
#    'wins': 110,
#    'losses': 51,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'HyDik0tquD8--v4jkqS-w9l5F4L8_DiyUy9YK9IIZmps2w05hBOMfDeVZEDj3roq4JxXPY9WECoSdQ',
#    'leaguePoints': 1179,
#    'rank': 'I',
#    'wins': 146,
#    'losses': 72,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'puuid': 'EE10M5JowN8vvvf5DYjSVpLfUNatb4cuS4nOXm5O9s03MjT98yxBqZESWdCXwDTX7XK4k4B5_H16mw',
#    'leaguePoints': 1177,
#    'rank': 'I',
#    'wins': 160,
#    'losses': 120,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'xLmtbNJ5_Ipuk-xcBfO9FaH30EpdprGExe24HrNpZlqb_WFkyqhhFDcqxMnc24XkeEIqundlYNxyTg',
#    'leaguePoints': 1176,
#    'rank': 'I',
#    'wins': 134,
#    'losses': 125,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'puuid': 'ic-3h0qnz_NJgdMBKQDGN-46fVDuBVf6tfKm7gh2NZSkuqIxrh1DpJMF_pSVg0U8w44u0b95AdwgHg',
#    'leaguePoints': 1174,
#    'rank': 'I',
#    'wins': 192,
#    'losses': 161,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': '_EKiOsF_uHJ5VUxVSwK3l314KNNq_aNYILffoCljv49fM4z2667dm-_kR4miJ4z98sTK69MkL3as5Q',
#    'leaguePoints': 1170,
#    'rank': 'I',
#    'wins': 130,
#    'losses': 100,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'puuid': 'L_3I2m6uZh6fpUFLH7S-7sdX_s3Lsqr-MZDvyFRB1YVozSOPTQyHDzze_4RIsn9fNolPMEKY8kf5SQ',
#    'leaguePoints': 1169,
#    'rank': 'I',
#    'wins': 107,
#    'losses': 40,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': '9n-ZbeHJooNruaxtdfq8wxVZ8Hk8kMEo_1J0-yPJxP6gv2cHRmOCXg3wwr65pl8jNFlMvYJfwiHtUw',
#    'leaguePoints': 1168,
#    'rank': 'I',
#    'wins': 192,
#    'losses': 151,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'puuid': 'yjQorUHjYb74vEPqbxX4EYpTpLF62otIanZN7OPSss6RMG_p8kDgV4uzyzXOm7oZvIF6MAYIZ_xeGw',
#    'leaguePoints': 1167,
#    'rank': 'I',
#    'wins': 145,
#    'losses': 129,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'ew5hch0HYK_n35OIcqFE3eySZD3sHvuMkf4R5g8ta16_eTKIL4Xq-ulF4IurQk_CeeQOj4sKwX9n-w',
#    'leaguePoints': 1158,
#    'rank': 'I',
#    'wins': 119,
#    'losses': 88,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'EdLUCour9ELeK4-GKt0rLeKWUNNboptaoIVcpda4ArgpIfJqydPDASSU7NeO5h-dobQfse97Q99xug',
#    'leaguePoints': 1157,
#    'rank': 'I',
#    'wins': 82,
#    'losses': 42,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'oERujVWqxWvXZciCrOunHbbdycwMzCYASU9qORHbaBPLjRu3qa_b0ctE9sm_w8SuBcNzj80nM3iM_A',
#    'leaguePoints': 1156,
#    'rank': 'I',
#    'wins': 182,
#    'losses': 159,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': '4nhz5yRrfnHJSXg38_Fj8syU7fVt1oy7izgrhR8RKEGXbneIQrFKQHwH2J-anqEu__ZP1Mny5SsyBg',
#    'leaguePoints': 1155,
#    'rank': 'I',
#    'wins': 179,
#    'losses': 149,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'xUKGE5801MvqLQUehjVfRZ3sHYAUI-50Yv4fQG7XHckV4F-uBAXmlA-A85-Q01pgDVuewpHKbTxgfw',
#    'leaguePoints': 1154,
#    'rank': 'I',
#    'wins': 97,
#    'losses': 51,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'puuid': 't4Daf-YIFB3MAKc1VayDxQxNePvI0odDEICGKlFx51uGNBsBzTPbyt_eGbz1F4TJtsY7m_7UOZ48Yw',
#    'leaguePoints': 1153,
#    'rank': 'I',
#    'wins': 106,
#    'losses': 61,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'puuid': 'OwOLiAl9PREpijr4sLk8PpMWev3uX5Si9WMkD3TQkEOby4LA6A9rF3kM5_mW-FC__qUfyGTd3jvzLw',
#    'leaguePoints': 1152,
#    'rank': 'I',
#    'wins': 132,
#    'losses': 91,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'puuid': 'v1HQ9LNfLWC8OhTBl0-FMgomHi8WvnaZUzaqMZp-m89RVlJHwvJ4uSQDv5Bm4firfXpU9ISQL2_1YQ',
#    'leaguePoints': 1148,
#    'rank': 'I',
#    'wins': 280,
#    'losses': 248,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'x-eEqhppLJeyoC0cW2kE4O2P29sRoQXNt1jeChG4r42Lo8bQ4zI4ct3gIB9NYX2vzSfWIJlHMZNdcg',
#    'leaguePoints': 1148,
#    'rank': 'I',
#    'wins': 249,
#    'losses': 218,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': '9drugiF1wKxOWP_5bz-qFh0IEMd_hdfK4k20th4N3XIIObQiO3IIub2AmbNGZUCgIJEy_C4YSNEMXw',
#    'leaguePoints': 1148,
#    'rank': 'I',
#    'wins': 79,
#    'losses': 33,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': '1Egjkh7P_LwELJ4toHSvkdnuqH9LhHn97kqkE_NlvQfMc4X4AAQ-asmLcJBMAFql0mgDoUrnKGl8vw',
#    'leaguePoints': 1146,
#    'rank': 'I',
#    'wins': 173,
#    'losses': 127,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'NATD1j-07O12fYfihmsP99PseRebBtOL_BRMu7rZTgpayq8HTmblReE2jK-Fr1INWdEeJuxFZhnkHQ',
#    'leaguePoints': 1146,
#    'rank': 'I',
#    'wins': 104,
#    'losses': 86,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': '7neZNKzwHqZlQgQdopV15hyF0vX0zQ7-Xvu_yAFl3MQxfiIUkt9iaSfOre5LNjq9Ci9i5vbYdEXQ9A',
#    'leaguePoints': 1141,
#    'rank': 'I',
#    'wins': 102,
#    'losses': 86,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'puuid': 'faGzuf78LEAO7uePIUszh2Ew6Gm1Rdk2to45Uk2zlDfdQa93cUp5H9Z9wa8PatM1aih0lFI8q0FvWw',
#    'leaguePoints': 1139,
#    'rank': 'I',
#    'wins': 104,
#    'losses': 81,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'Nju0ASTSyw7kyqJqP7J3vZWjxbiQ2jz2SIQ40xHzsMHjYw4FiNmC7xbiq6m7KQ-cT_p39zFqxycXvQ',
#    'leaguePoints': 1136,
#    'rank': 'I',
#    'wins': 104,
#    'losses': 47,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': '1XpDZ-ZfyZs80GfDihEnssLyaIGEHdSEzqpdJDUqW1UW50xWpilybTFlNO4H1NnJDrx6yd7TXColuw',
#    'leaguePoints': 1131,
#    'rank': 'I',
#    'wins': 203,
#    'losses': 168,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': '_BGg3KrIa67s1HqfRh2s_Zy4rK8CvBfhivmLHKhZQ3tpr15LYsKnI_SyqdYX5vfr3m05wNoPVfdOUQ',
#    'leaguePoints': 1131,
#    'rank': 'I',
#    'wins': 81,
#    'losses': 62,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': '8X-8x7wkNVsQSl5-f39voQgwizWjh42nuzdKVtWfAPIo7c2LZf_5gvGLnEERhLN12PJCLEprvQTyMw',
#    'leaguePoints': 1129,
#    'rank': 'I',
#    'wins': 253,
#    'losses': 197,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'IlZNB1NC-lIOyeKsyLvbJChAwPNAKrpc_7ZEg8t_t-u82OgopqyDvQ4dHdCCUJE5hVlY37X5MPFIgg',
#    'leaguePoints': 1127,
#    'rank': 'I',
#    'wins': 86,
#    'losses': 17,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'puuid': 'PQwEvs0TxJVX0skLC7UZknbUud-8Wg8hhxP5mE2mNUiHGhdGhlM_4qct1S-Byn1hN32ZKp9EbD6Uiw',
#    'leaguePoints': 1126,
#    'rank': 'I',
#    'wins': 118,
#    'losses': 96,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'puuid': 'Em5F9jfbmHZwsRL0-eoPIoEmSk-75YB6rkiE6mcNfoAlnqMyRBbkgMAVnzMTAeDKAwdwOheTtB-HKw',
#    'leaguePoints': 1126,
#    'rank': 'I',
#    'wins': 108,
#    'losses': 73,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'LlFu3gVXOPdPUdgOhyxwyrmxudRbf-wu3qlGMm-1iFYbdBGd5hAg4aOuMarceMxyyOqBR48pE0qG3A',
#    'leaguePoints': 1126,
#    'rank': 'I',
#    'wins': 94,
#    'losses': 51,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': '6Xt6dN3M0H5SNdkzeJ31wlguarSEyg2h_14tGyf1WjxkuG7qOd-KFQltuRkw5WTyGY6nVuUmjV395g',
#    'leaguePoints': 1125,
#    'rank': 'I',
#    'wins': 176,
#    'losses': 128,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'beC57hfHFKfIrVMcTzWWuu5Qw36zaiYgZsnDg8S8exCH-JKzJrQxZsXTTT8LeXNRKUF7W9lCkcbqqQ',
#    'leaguePoints': 1123,
#    'rank': 'I',
#    'wins': 104,
#    'losses': 89,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'uQXaskzIm_WA9B6_fZzNracW-EBRb2EGS59IQMKplyMb-mL3BLZKoPnxXA5shqe133R45THoTpNaUw',
#    'leaguePoints': 1118,
#    'rank': 'I',
#    'wins': 199,
#    'losses': 147,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'puuid': 'TGmx4SotOPjBMPEh459BoDUgJRGgY3hVDnn--FMEPS3QuyxIDoX37orgQb0CObFkr_EZPfssU7R_vw',
#    'leaguePoints': 1117,
#    'rank': 'I',
#    'wins': 74,
#    'losses': 45,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'FSCI0CX-pKSdc6xxiUEd-E-rgMxaSetB_wzMntin8jaEkb9eGMcGCnvi_irwXt-KIE-WIUgHc26YCQ',
#    'leaguePoints': 1115,
#    'rank': 'I',
#    'wins': 108,
#    'losses': 92,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'U2byYsw3moFsD7lLXZ5de-JTeOg4CbaSOeLo-fbBJb5MHS2TYoGdfOBN3QTYvs6y9P0zftX0Z1-0Cg',
#    'leaguePoints': 1111,
#    'rank': 'I',
#    'wins': 148,
#    'losses': 133,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': '3TFs_6XyVMVM5lrOnY-dkxHSq_Sr8OBM0FSIms_jF3xlqqPH4Il5s_x2euZRUucvboNAUDkInfdgPg',
#    'leaguePoints': 1110,
#    'rank': 'I',
#    'wins': 114,
#    'losses': 84,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': '_2MHqOt-IQ2u85iCS1BQpgszFm9JhAD9LdAmqhS95S5GVN03o6-2kbLWXbzgwTA0L_3lP7YDdgIByQ',
#    'leaguePoints': 1110,
#    'rank': 'I',
#    'wins': 90,
#    'losses': 54,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'puuid': 'pmsecoS5GsZ3VGN0YxPp21LwiEjeqk_xsSfQ4oK86l8ZFZrnQVrDwPJIzHYuaOYXlJgcADx1vW9bUQ',
#    'leaguePoints': 1102,
#    'rank': 'I',
#    'wins': 168,
#    'losses': 126,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'puuid': 'RZJFm5ryW30QSB-y3PwkoEyW7f8DMa9JEnVkQPFnEjMg3UhgyNZ1FrVLUDWhkZ-kvHBWvVcj5o4rAQ',
#    'leaguePoints': 1102,
#    'rank': 'I',
#    'wins': 97,
#    'losses': 71,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'puuid': 'hi5R3RdveMXOnZzY46wHt239TQdF4r8_lK4Ws52eH5CrwExM_524pjiD1N5bcrE-LQWrV_zEozvtbA',
#    'leaguePoints': 1100,
#    'rank': 'I',
#    'wins': 110,
#    'losses': 72,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'FeID3jQfXeL79DJvjHmSwIe5Cmwqy16X__hpuQVA5VVCupQuaNL7VAaN0UR1wY3vRejwf-mqGEqFRA',
#    'leaguePoints': 1099,
#    'rank': 'I',
#    'wins': 107,
#    'losses': 75,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'puuid': 'G_jS_5Z9akjQLD-EKpq4wZiItA56ah3hiIboZECDJCGzaA-zj17LN3InV8KQXJySx4uPIfgrzcmdIQ',
#    'leaguePoints': 1095,
#    'rank': 'I',
#    'wins': 109,
#    'losses': 66,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'puuid': 'yOMoBNvmWTsoMo5qn_m6XB4WACTntwHubklsF2LvkfPez7rqc5J-jYkRSM-dJiOEMDFOxL7lQKoRjQ',
#    'leaguePoints': 1093,
#    'rank': 'I',
#    'wins': 128,
#    'losses': 73,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'ri-PS409mzRKXm9JAtWePqrtEM_1WjHSAsU6k7B9_yfC-zpgm740spsN0nU9KXgQkKb-7UlBNJcisg',
#    'leaguePoints': 1093,
#    'rank': 'I',
#    'wins': 117,
#    'losses': 99,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'qRod_awUCK2nFYy5s6FJWoqkdxGR0o_VtbExL8fKGniI4LZ3cV8Kklfrr9iEjaZMcnQWdjoVTGsoDQ',
#    'leaguePoints': 1093,
#    'rank': 'I',
#    'wins': 106,
#    'losses': 86,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'puuid': 'X4lLDSSIwtUaJEgAaTlPCu02uoXb4yJGe3uQYeP05WvUiUZQMF0_UqAgAX42MXn8tJ3wzOuPOYfRaw',
#    'leaguePoints': 1090,
#    'rank': 'I',
#    'wins': 121,
#    'losses': 74,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'sMqmSYQ-EZz5ZBI_rY9j4rh7k6OpqYlkkXt-g1Sbupu2_l2vguOL6qjVjKW42mBV5jQ2pC4YfHtqvQ',
#    'leaguePoints': 1090,
#    'rank': 'I',
#    'wins': 79,
#    'losses': 53,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'puuid': '4mTMGuwzq8I2TT_MgtUKw_3DWAMkhBfjqT3kniHi67ooT_aXuok47ua2ZsleUPhs6b4upjkwKg6a3w',
#    'leaguePoints': 1087,
#    'rank': 'I',
#    'wins': 167,
#    'losses': 124,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'puuid': '8Qkgify6cXc3_xkZNFN-umZu5EuFFIOMKopxfa87I3k51JcAkAHnMZie_RL5z_gmPwl-UybBMg5JQg',
#    'leaguePoints': 1085,
#    'rank': 'I',
#    'wins': 127,
#    'losses': 109,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'LF95FLvNxIfrVglQIqNjgm4oa3weNUBO1ryO0xWYNaMU5Lobdcp-c0ehtvM37ULWn0yrSGYqw5vN-g',
#    'leaguePoints': 1085,
#    'rank': 'I',
#    'wins': 64,
#    'losses': 43,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'puuid': '0U66qIyqVwTI6TgQlQhsoz1fDfj4T0JtJnxRewxOHRubsj3pfWLAQIi1oZuel4DETU-Bk_gpLnSK5Q',
#    'leaguePoints': 1082,
#    'rank': 'I',
#    'wins': 84,
#    'losses': 42,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'YI51nBqhBgCOrKUVeWqP-ryjKh-A88Qtqf-r6gpT6YDfC1hbCKoBUfur2_Anuy4Av897iwBccGOK-Q',
#    'leaguePoints': 1080,
#    'rank': 'I',
#    'wins': 158,
#    'losses': 119,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'puuid': 'GXvvvrIYOYoNHGlUnVfyp-DZFg_TF5P9EXWn8gMdgqYToyFIhXSGwisjuTifHnDUBP7Ljt9HOe5EMg',
#    'leaguePoints': 1080,
#    'rank': 'I',
#    'wins': 151,
#    'losses': 102,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'puuid': 'wyWphlMy1YJmEHiy4cV2acPzpIuD9gRcnQ-5cVRY-riFbkMVAcEHgIRbG9VtUoApUCAR_u0WFkfwEA',
#    'leaguePoints': 1079,
#    'rank': 'I',
#    'wins': 84,
#    'losses': 66,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'TEbaLtKqVO8w___pHHjVgfLzP73WK9fc3z7kgTY4_3xHTOuNCY9D_z2SIyqx9unDj6dzAqCtp9bvMQ',
#    'leaguePoints': 1077,
#    'rank': 'I',
#    'wins': 74,
#    'losses': 26,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'kDqUIj8Owjqf32xwA492KsQhOiGgswA4Ab50sYCkJH0nxB3JwrNcRMB8Egt4H9A-ajI3vloOlSlL6g',
#    'leaguePoints': 1074,
#    'rank': 'I',
#    'wins': 91,
#    'losses': 71,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'WkUV47i2SCnppUkPU5eJcgP3kSak8dWmj0Lu-uYVVxHUFazITexBsY5agjXQAMmjRiBSGE9RRVkLOg',
#    'leaguePoints': 1073,
#    'rank': 'I',
#    'wins': 112,
#    'losses': 86,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'o8Ji5Y6yAIN1shORcy5toxKkjY6oHG2kdWeaf1JSU45pDJ8s1BW2kaIyxniKalzmEI9ff9tpVkrcPA',
#    'leaguePoints': 1072,
#    'rank': 'I',
#    'wins': 93,
#    'losses': 84,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'ynPGOP1a86fRC0PSrPPg95Hsb5v1xkHwpM_KUyufJdw0ZPguyCiI5-loeRKaAWY-s_vSiDnPqwUX4Q',
#    'leaguePoints': 1071,
#    'rank': 'I',
#    'wins': 113,
#    'losses': 82,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': '-18mWhRwfOKYp54GvZaXi8hr16xK6Ld3jH8IgRxH6vlAvEzR-At_NqxgoIHvBrpNR48AxIWT4Z8Fvg',
#    'leaguePoints': 1070,
#    'rank': 'I',
#    'wins': 109,
#    'losses': 75,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': '_QCri30M5E1aHni1kn_zkeS9CNDVnMwvaDxavFw4b13u9vyhcq3lXJseHmzmNf4pXEop8wqz540SMA',
#    'leaguePoints': 1070,
#    'rank': 'I',
#    'wins': 107,
#    'losses': 73,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'OM8XXJqhz4S4c3br6Nc5se9-xnALi-40EJRQPYP2uc-F25frZYayfuO9olUXW_TRgS6gq_nXc1VK0A',
#    'leaguePoints': 1070,
#    'rank': 'I',
#    'wins': 101,
#    'losses': 82,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'bOuGcABjWgZaD4Dkyya-_l2vU7b4mQ2IqY7-XWupn0XhFKAFIczqjLH1Gxg8ODQWQGgP-ZoEA4embg',
#    'leaguePoints': 1069,
#    'rank': 'I',
#    'wins': 142,
#    'losses': 116,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'p0a-NKwg5I1jrHJafRppl4v3B1DQCN1nq0lMtE9ApHLy4A9UU336U36PkOuAgx2xP-cUcycweiKRDg',
#    'leaguePoints': 1068,
#    'rank': 'I',
#    'wins': 154,
#    'losses': 119,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'puuid': 'ixOmvlGCOxq2LnpRefzLTTeixRSqz1lQx4-iTgfasI1FXopHwNPqpAc9JBx81xI4WilZL5MXITcueQ',
#    'leaguePoints': 1067,
#    'rank': 'I',
#    'wins': 90,
#    'losses': 59,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'puuid': '4IY3wH6ZcRuNc3Sh_toMLnXjTMRNteRmsAhWEhScILbS_I8voFbH0ohL3NW1R_PDn5KqcOFJZ0sKoQ',
#    'leaguePoints': 1065,
#    'rank': 'I',
#    'wins': 155,
#    'losses': 117,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'puuid': 'uR87KsPlXnf2nuUgB7lngP1VOGC5AdNPibRN5fkneiP6hu3gbSyVz4LabPxEL5o8K7JZv59krSe9ig',
#    'leaguePoints': 1064,
#    'rank': 'I',
#    'wins': 283,
#    'losses': 255,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'Ly1xbpy-GLzb4JboCV2_k0sZa-zRYMCu1WPhbKLVMPE1vqiVZNbkxSZAAYg1LQlm6MEPlLMXEdcafg',
#    'leaguePoints': 1060,
#    'rank': 'I',
#    'wins': 60,
#    'losses': 32,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'puuid': 'mFPn5R8zSzYG09B-wm_Azvfh37axLyRnhemkOKj_FbGcoQMS5S2hIIMFYCQ_febRKAyFakzw7XAx1w',
#    'leaguePoints': 1058,
#    'rank': 'I',
#    'wins': 105,
#    'losses': 92,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'puuid': 'HENQ_Fc1Iu-lPwHyDOs_YxlLIhR18uXp743kc3ZUmOhr23fC9OiYAyiT29TkQ0FWFH-k2w34vMUdbA',
#    'leaguePoints': 1056,
#    'rank': 'I',
#    'wins': 257,
#    'losses': 225,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'puuid': 'ZosWx4OGlMYLPPS3dm90550DfM_2g8QPghHXQXBp3X-_f97aXIlOvnc5audSsJbLKGhKhmvicPYZcw',
#    'leaguePoints': 1056,
#    'rank': 'I',
#    'wins': 214,
#    'losses': 183,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': '12D6xOjRiREn8XWxljOutV2QiwYn96uFi75ikLZxtx2_cvWZ7nPaFKi_Jy3ogMZI3GdoF-MiMBjmJw',
#    'leaguePoints': 1056,
#    'rank': 'I',
#    'wins': 103,
#    'losses': 89,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'puuid': 'H3rmue_Zrtm0qXwvwp1v7epKB02ZDx2Qs1gEMh0D_Go9HOq4KB_FtJ97Taw1zqr_Ljlsf3nR_K_zyw',
#    'leaguePoints': 1055,
#    'rank': 'I',
#    'wins': 108,
#    'losses': 55,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'puuid': 'cBpwO_T9pWAOsazAaWHjP7P4AdOigUmYL0nol1pT9g0EcZPVeW1k2ShhlejCP_aeRe1ktgkN8_EUBw',
#    'leaguePoints': 1055,
#    'rank': 'I',
#    'wins': 74,
#    'losses': 53,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'fSpiy1gkwL3dCLMrIx9a3HXwXewifAgEmH1rRD9j80OLAkNgGzyA3-AV__sbbU9-1LebOuT34FXA6w',
#    'leaguePoints': 1053,
#    'rank': 'I',
#    'wins': 171,
#    'losses': 136,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'puuid': 'lFGmCzPSdafL6gUvUYWJ2EPjTlobMjsvepom-EwOKNiBgCICh0B4EP1gPcbTkBmu9nEXfYIgjshdTQ',
#    'leaguePoints': 1053,
#    'rank': 'I',
#    'wins': 75,
#    'losses': 62,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'puuid': 'ptDkiwO9n4gLeiCEh6Wm-AkV-l0TTDuq0TVhS73mEY5KEl7hVy2OnWiXXVPEeWGXCqvxXI6PnlTuDA',
#    'leaguePoints': 1052,
#    'rank': 'I',
#    'wins': 223,
#    'losses': 174,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'puuid': '2Ol09t9AMt0azu0ekmFExnPeEnmZFJgJ0g9LYinZaC-afoyHkZR7ccDD6Z3l50HyVdRav_RixCTdUw',
#    'leaguePoints': 1052,
#    'rank': 'I',
#    'wins': 134,
#    'losses': 93,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'puuid': 'Bzb68l0ccC9SMjHJsOETqVyjtmY07GH3Kp0sWH7Cxto2P7EXosuE9MYDzPigowKS0JVWUBa5CmKk0w',
#    'leaguePoints': 1052,
#    'rank': 'I',
#    'wins': 96,
#    'losses': 73,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': '7KTOIsDTwgQZkM6aMnoPAtu0bpCjlpf3pWuBx9fksmvM7vlcUogms9HM_LT6Ptgr3v377aQdGyhTAA',
#    'leaguePoints': 1052,
#    'rank': 'I',
#    'wins': 87,
#    'losses': 69,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'puuid': 'tRlNf_4I4agLjx6kbHOJ9PIwEoqHhD4VRgV1zLVt3ideoNpTbWNulVO91TAlP5KDrF89SMSm9wlUug',
#    'leaguePoints': 1051,
#    'rank': 'I',
#    'wins': 111,
#    'losses': 82,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'OEU7Au1l6fboijwUT7YXw7mQZtPfV2LCWmS0DdcOkk7h-OgqZfzY-3UwEqTw3vRrAXKsOG9xOZgE_A',
#    'leaguePoints': 1050,
#    'rank': 'I',
#    'wins': 147,
#    'losses': 117,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'puuid': '1fZwgrHN9WYs-MJwzRK9NsojXEcJsxILBnYLIC7UoBxY6Kahnc92kXgSvbdih7icBqmeK7sX0hWEGA',
#    'leaguePoints': 1050,
#    'rank': 'I',
#    'wins': 97,
#    'losses': 65,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'k5DGYTAEj6lfarckVDaXxrmtNzkN0ngjVz6C2uWFYuNyDb2KF43wWJRzmJgXBQ-jmuDUTZs_xCjUSg',
#    'leaguePoints': 1048,
#    'rank': 'I',
#    'wins': 122,
#    'losses': 97,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'Gs_RUy9L2FXMRErnAvwin6KydtGltpG5kV_Rq1g8u8S60mDFaFbg6FOb1PzUcPs00WJZb9GkVLIyTw',
#    'leaguePoints': 1048,
#    'rank': 'I',
#    'wins': 121,
#    'losses': 91,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'BUk8u2CuTt74g4YED6Wcbh8BcsEwhs2C8iAqtBRaTfaNhH_FMPXyNRJRXfzSNwSXheeUtx5lzngj5A',
#    'leaguePoints': 1047,
#    'rank': 'I',
#    'wins': 118,
#    'losses': 89,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'puuid': 'Labq-tQdDYMHgzrTCaY7qx-TkzqyCoDDGDA68RvnDl9DeMKdk9hSw8unU1jMoDX-w0A6AfHqLK_ieg',
#    'leaguePoints': 1044,
#    'rank': 'I',
#    'wins': 169,
#    'losses': 148,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'puuid': 'veOuH-bwcENT4S-O-PX1CpNrFFOgQIxq-RdJVDuPc6EGXOtFHnhvOS2WgzcvkAVBJuZVtbSUYYt1vA',
#    'leaguePoints': 1044,
#    'rank': 'I',
#    'wins': 127,
#    'losses': 90,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': '8km-HYiV5UScMLkOJIpOyDkVa-s3u7USTbMQACuMvx8DdKJui1CZUwr3hyMXIqr5TKGLBFOLU4tXEA',
#    'leaguePoints': 1043,
#    'rank': 'I',
#    'wins': 157,
#    'losses': 120,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'puuid': '8xKanYzxbPNN76-lcg2aL4Y8mR2m5UMnZEBZVCbQStzu83ceniizGyDwwPKlKZGF9yTdWTtpUw4uJQ',
#    'leaguePoints': 1042,
#    'rank': 'I',
#    'wins': 104,
#    'losses': 85,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'puuid': 'eivOFhMcPnGU07ppxTgQAWZ6rQQCcKs7eUT2MuS5e9sXtyPGGrh7-dUXpPdbNDc5ntf2e-IahivNLw',
#    'leaguePoints': 1041,
#    'rank': 'I',
#    'wins': 129,
#    'losses': 101,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'puuid': 'WygWvCUVkSDTOYkLZw6aO4v5qMMvnl1yo27UZoJpkJZhjGtE4gw0jBtbnd4SkUBXKhx9a_saqziPpA',
#    'leaguePoints': 1041,
#    'rank': 'I',
#    'wins': 89,
#    'losses': 42,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'puuid': 'ZX475iJ7E2B4e6gUCvVk3_H5im08qGKYYLHpeNqqk04ghVZDII2XFa1YedsmJMlJIMGfREwKk_uXRQ',
#    'leaguePoints': 1040,
#    'rank': 'I',
#    'wins': 210,
#    'losses': 174,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'puuid': 'GyEVfxJqWGFUuM895VhxpCvn4mrw4ZJpKH-jdPseWnY0MEvF610EM7xoVn5MagiB8wTS3pTMerG1PA',
#    'leaguePoints': 1040,
#    'rank': 'I',
#    'wins': 133,
#    'losses': 104,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'r9hIcH1mGZdMOghhH1E2qNAdv9EzdCq70pi2zeBj8NNTuaebjC-D4lgtzypJcyHC3cAUbnBbgtsgmA',
#    'leaguePoints': 1040,
#    'rank': 'I',
#    'wins': 100,
#    'losses': 68,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'a24c1B7PjJFPKAZz2Y32Xzf6FzGavFaiz1MB7si68B-kJGl5kNoG-dKNGuPYpeNGyLgsqw6Xkux48A',
#    'leaguePoints': 1040,
#    'rank': 'I',
#    'wins': 77,
#    'losses': 50,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'uBK8Wbnh5z1WCGoB7k4wfvDiPiL4bvW_bHDvmsasipU8nVbSJPydEvuS4b4OfXa6vUAREF8WbmGxhg',
#    'leaguePoints': 1040,
#    'rank': 'I',
#    'wins': 71,
#    'losses': 48,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'puuid': 'SqCIpg5UAKUH3kAhZx4Ui1PfAdZusQSg27AKvp5kcYEEQUOI5HhtmOc6LHUqPnYBdbqDK_Ef4h9k7Q',
#    'leaguePoints': 1038,
#    'rank': 'I',
#    'wins': 211,
#    'losses': 167,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'puuid': 'Gf9Yfo2khZ3YXWLzevmCnmO470c_uz06zyIYASu9G90B6BUWwDFahe5w-y4kdfmE-uIo_LrHOLGNpw',
#    'leaguePoints': 1035,
#    'rank': 'I',
#    'wins': 117,
#    'losses': 84,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'puuid': 'HRjk97Wh4qyCtb_fdDtSgYPz3HghCpuWg3JgyM6VkwF4THn0Ec2jiuaqQvpULgyCGPHC7S2wBlj0Ww',
#    'leaguePoints': 1033,
#    'rank': 'I',
#    'wins': 123,
#    'losses': 81,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False}]}

# %% [markdown]
# The important information is stored in the `entries` key, so if we pass it between [] we can acess only this part of the data

# %%
resp.json()['entries']
# Out:
# [{'puuid': '5UKAB3BdAjfwztS7ZkHQPd5F78ioiLIDGawV572j663hp1v3k_8-NcyHBxH1S0a5Oj_6Qq00VCSURg',
#   'leaguePoints': 2123,
#   'rank': 'I',
#   'wins': 200,
#   'losses': 127,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'puuid': 'RSv3jqMfNnzJdOQtFj1EJQD6cb33vNTkChk80eqjQxIIKZSza7fy5nnrVlsroMZCaqcj4cLn-7otbA',
#   'leaguePoints': 2110,
#   'rank': 'I',
#   'wins': 210,
#   'losses': 84,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'BuSj5sCliNI8TMAEOj6YEQ8qCaANtfjR1ggshJrYEtknF6jgouk0Sopi2wf89hbYA9kMpTkZxUUiHA',
#   'leaguePoints': 2000,
#   'rank': 'I',
#   'wins': 251,
#   'losses': 144,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'puuid': '27uMJ1ScPoerO8mnOHwAdb40__AZmUZgCuU7cWzcgseMUghYzYW-ORvexyHjAeoPLsUX88kEsw9pzw',
#   'leaguePoints': 1967,
#   'rank': 'I',
#   'wins': 202,
#   'losses': 76,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'By-BwlILMKrhWd6etoNg9xBdh9r1MNAaZtunZqzKJWTJ2U8TNMUEr7Yov7uErgjo_AS_GPapUm-Vxw',
#   'leaguePoints': 1916,
#   'rank': 'I',
#   'wins': 127,
#   'losses': 68,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'rq0iCYnzfTgF5itI472beFCjRP_f5M22OowpJUpvXYgSINFOQlbwEC43_hY2MFg_Z3i3_NsWWHLtjg',
#   'leaguePoints': 1855,
#   'rank': 'I',
#   'wins': 208,
#   'losses': 139,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'puuid': 'YkTi5xik8kQp8N0wEWQMMkm0gDECq1dwgz_VXRETHvLHALCT2D1Ou3g_yxJkApQdLMs7HaPLjdiw6A',
#   'leaguePoints': 1846,
#   'rank': 'I',
#   'wins': 129,
#   'losses': 70,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': '44dHU0Pa4LAtTjCtg-7atvW1a1Aus6qPDr-lWRONuPR5DwJKQNVfNv_d1y4XDlWTh2ZS6XKJtNqJWg',
#   'leaguePoints': 1823,
#   'rank': 'I',
#   'wins': 195,
#   'losses': 127,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'DAuoX4AO20IGfNaq0g7mPKKremTChU6K5o0XlP5vuhtez5P55rpYTAE5vWYkFwDW6ymLoW-0VtYrJQ',
#   'leaguePoints': 1823,
#   'rank': 'I',
#   'wins': 170,
#   'losses': 104,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'SZUaH41CZbmZUuhdG9BWuqDMQK3rrGctVe4OK8JlRopLl3JIM4iDHyrcWWff_MiIk_rERLRUqc3pwg',
#   'leaguePoints': 1816,
#   'rank': 'I',
#   'wins': 232,
#   'losses': 149,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'R3_dve0GhEF7DVnafrizMG2WGBwcvg0sQJSjKNM2iMFaWNF255aY7eGyFXEDXkR7RrKAmG2Buy-xyQ',
#   'leaguePoints': 1783,
#   'rank': 'I',
#   'wins': 106,
#   'losses': 45,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'Py7vQMc-nU3qj23MWx-p8vsun9gbVKGRXRMjdv8eSdesz1LvB50Ra8Oo1-G0WXbxSmzX3DujxnUQqg',
#   'leaguePoints': 1769,
#   'rank': 'I',
#   'wins': 230,
#   'losses': 133,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'PDrjb8JwcFHCeOEPj0Stb-FRFRYrzZQzjLdGOUQYfokV18i8dlKdgT18Vx4ZG8Ep60uzO35g_YEj5g',
#   'leaguePoints': 1750,
#   'rank': 'I',
#   'wins': 141,
#   'losses': 98,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'puuid': 'D10B-FyacCQoFLfM46RiRVAHapH96-vFUFmTUGIbdbbSoFpGJ-41hCllk131G0uwuC0cLKM3Mex5LA',
#   'leaguePoints': 1747,
#   'rank': 'I',
#   'wins': 87,
#   'losses': 26,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'ACWtsgRYqXnrp4SlkgiJgmbEPHtGrxT3ckZZEWDpuwVSC3zOCJeuIEvkVhngFgJ5xOT67kZyOptrdw',
#   'leaguePoints': 1688,
#   'rank': 'I',
#   'wins': 283,
#   'losses': 228,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': '53F4ojfxhzgg2JW2U9Du5Byw_a4dr2NRzUdHjUMXvAbXqlmxEYwVwda50PXAtbiVVJCKOWiYeUEF4g',
#   'leaguePoints': 1670,
#   'rank': 'I',
#   'wins': 169,
#   'losses': 108,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'puuid': 'UthokLVweZeBnFFQP5fiagbzH2ryP3jW8-dTdztjtPVTOiMgzKJwrFVigOQpk_OQ7tQEnSFwkB0LoQ',
#   'leaguePoints': 1665,
#   'rank': 'I',
#   'wins': 201,
#   'losses': 143,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'puuid': '1TR9typj2wI2hiMEwxNlYZB2xGiDIaO2R-FupaFUOKktYngNOkWL0FZSHJ7lMx5Vogk-Qebi9qQfYw',
#   'leaguePoints': 1653,
#   'rank': 'I',
#   'wins': 182,
#   'losses': 134,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'L7rG9jcktBxNZqqUimchm4KmCTQ5u1ZAR606JRc7pOSsIchDEVXHv1wcxyiAsObl_uc5MqQL985pGw',
#   'leaguePoints': 1647,
#   'rank': 'I',
#   'wins': 171,
#   'losses': 109,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'VsDAa6jRol0uRmcc3RhIMBaXYmNs_AKbaf5XYcZ5Jzd0rcUgzsFtrUJ6twZDxYTzsv_VewdbNl-NrA',
#   'leaguePoints': 1611,
#   'rank': 'I',
#   'wins': 154,
#   'losses': 113,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'puuid': 'XgoNG8USgbF0R1PxsyR0RBGC5XsaEyAAgB_WUhUmQCTF5vK5UqDPKSeXv9Sbpo8qeNV4wQuWTa9TUw',
#   'leaguePoints': 1599,
#   'rank': 'I',
#   'wins': 130,
#   'losses': 78,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': '2Xox_92OYzRRmJGVyMxidZwF4hh61mBUfp3sbU47yAxcbvYDwuJ_qfRlALEvCZWSO0qAMihzhle6ZQ',
#   'leaguePoints': 1583,
#   'rank': 'I',
#   'wins': 212,
#   'losses': 142,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'NLYAL1RSw7ql_j2eYx0-7KVWSUz86Hy6pHo6wNGTzGnMZ5rvOu2pMXno6a5jn3fEEj9Kh_2PTmiXNw',
#   'leaguePoints': 1570,
#   'rank': 'I',
#   'wins': 114,
#   'losses': 64,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': '__layBs7vjIcxV54c4SgJxRNT7-njkK-KuuUvOZLKx_xgmBs--GY6ZdBJpq3Ue5C9FhAM27EZ3h2mw',
#   'leaguePoints': 1567,
#   'rank': 'I',
#   'wins': 277,
#   'losses': 192,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': '8yfB3oJvXq_hCaZGO6TtHgcU-X_6obKJJ9CuH_sg9L3N8Y4GSt-EO7_7SVDzFwuReEOXoWfIY8Emzw',
#   'leaguePoints': 1567,
#   'rank': 'I',
#   'wins': 134,
#   'losses': 83,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'NMxrfz2StKNLhYqR7Evj8fLtTJ0TWzTetgOgJmpJZ3se9yVDgEyWPQ33Yu_23OujbF05jl5DqA1tYA',
#   'leaguePoints': 1545,
#   'rank': 'I',
#   'wins': 256,
#   'losses': 197,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': '-TmFVmeQCk9rwlg1cV6U4iw43ZYC4JZZbeAKjWGtLaKJnjggg6LytdtIKwsiOp-HEx6JwaUjx93DLA',
#   'leaguePoints': 1518,
#   'rank': 'I',
#   'wins': 137,
#   'losses': 95,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'puuid': '8Hv0X4oWPAAk0xfhr2xVmVpajycIqM3CVAj3cn6CBRHwEgBf6mx-PybyJ-TSkn6BcmXBIq-uIXittg',
#   'leaguePoints': 1509,
#   'rank': 'I',
#   'wins': 85,
#   'losses': 46,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'puuid': 'XGLGRHGKx61-Nu6wsRjRPPTDli03EdfL_82D61ic8t80QSsgbrXowgA_POCJHFFy5CnwNEmRBHx3UQ',
#   'leaguePoints': 1508,
#   'rank': 'I',
#   'wins': 181,
#   'losses': 108,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'puuid': 'yCR_giBkxY7nz9zoF9P6hllfeLCkjh2r_I6xVzQUtTRiv2-F_G2UjpqGSY3OzCbg3lHjKEiiIWsEng',
#   'leaguePoints': 1500,
#   'rank': 'I',
#   'wins': 97,
#   'losses': 27,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'puuid': 'wQjJKcqfTbodhvXA0JKihgiM_N0ms0vjk6KZBlELk4Bqt6LkW3bO7U0A_zdSLgNhcL5Ih8eTleQOKg',
#   'leaguePoints': 1487,
#   'rank': 'I',
#   'wins': 325,
#   'losses': 258,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': '6JY7vYH56v7KHavmSLeJ7v10qHwBgzeoFtMn0y6BMD2haCPclq8nWbKdL8J_X4YBtadSjlG_nJ_DIQ',
#   'leaguePoints': 1487,
#   'rank': 'I',
#   'wins': 101,
#   'losses': 64,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'puuid': 'uoiOzG_EJ3sfbVAzOEb8_YfcY7szcNYSmxaLNzUpP5PveeJA10myRs5DhIBbq-B7UDVYNPFP-5anbg',
#   'leaguePoints': 1486,
#   'rank': 'I',
#   'wins': 142,
#   'losses': 82,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'g4x6NGXaltaZKaQmBTg2yMj9NlUzMoA3ZAWMYxkrbKIk7nZopRjJSnSybJ26iGBwVIjXRqkOyvqQ-w',
#   'leaguePoints': 1478,
#   'rank': 'I',
#   'wins': 171,
#   'losses': 128,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'qojVmF-FZJBy9yjt7cM3tJ36D5rn7A8RpklqFWTeu9Ipl_3AQVZr-Mwu6hIxEYLxXgIWXXTo7cZzow',
#   'leaguePoints': 1475,
#   'rank': 'I',
#   'wins': 132,
#   'losses': 77,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'hkWnzNLRNVhoxtBjrEg8XYQFbT40BQe0877fdOnClp0U90ovynmPOuBbFk2BMbtn6yOLiXBR8pvN9Q',
#   'leaguePoints': 1466,
#   'rank': 'I',
#   'wins': 184,
#   'losses': 134,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'kf47Rccw3lufXZrerKJsd-iael8xSNuAZ5SjT6-DI96qsoKpZdih1wCP1jTiWzyrHu8qjrYoWPvZUQ',
#   'leaguePoints': 1457,
#   'rank': 'I',
#   'wins': 262,
#   'losses': 212,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': '7NGUotBKtuz60EsTRphCywAyzwW8M9_baPdvv_kSirqQzAwq9J0-uF4ON9o8PG1K5-S6OJWSPBpXMA',
#   'leaguePoints': 1449,
#   'rank': 'I',
#   'wins': 123,
#   'losses': 98,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'ELcSjSqOLZS1l3YeKd208dpavPtHvZkphGCGcACykqdrTo1TxEntaCJooZ-3deCxKSxMmiGv-fA93g',
#   'leaguePoints': 1447,
#   'rank': 'I',
#   'wins': 192,
#   'losses': 127,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'puuid': 'Tif3xJ_0XR5nVWLTRCpArwzUaqlVEf5oh0b9xW-xwBZAU4TlaU_hCW6xCyWw3IF9KngCcEZkfhwZbQ',
#   'leaguePoints': 1446,
#   'rank': 'I',
#   'wins': 140,
#   'losses': 67,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'puuid': 'QhWuYMxKn49LaC8gqkzomCfNYLBq2AA1LAUsAhXtpTvMrs9reClUXXhWXMqWPkb5WYssLmBE8olPog',
#   'leaguePoints': 1416,
#   'rank': 'I',
#   'wins': 153,
#   'losses': 112,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'mwiZ1VbvW1mgfZ28DqJGfmwcG8SFwClaIB1cpW9wRkt5p7sNqIXfzG88o0HOFSxh2kdNGrOGZDXVrQ',
#   'leaguePoints': 1415,
#   'rank': 'I',
#   'wins': 164,
#   'losses': 121,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'rmEIM_1RsnyF3ShAJ64ZUz_iJ0VxXM9PM__x17ayoE00EoNcRkkthXnZSSZT0yF5lP15qwGp1tioMQ',
#   'leaguePoints': 1399,
#   'rank': 'I',
#   'wins': 147,
#   'losses': 116,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'WCKvQQ2MWMm97L8HEee8mnwGcOZ43IAVm7VwQQ6JdNZfP3tH8sqN0KhLeBUr4kGQZh388dSoHopQrQ',
#   'leaguePoints': 1399,
#   'rank': 'I',
#   'wins': 124,
#   'losses': 67,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'c22wkOk_yw2SMRt-X2ZewqdgniPCcAgHs0DbZWXm5WfKzRDR1JNgPN6wW7W4mDeaHtCelsbgV6-0nw',
#   'leaguePoints': 1392,
#   'rank': 'I',
#   'wins': 114,
#   'losses': 70,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'rIv0DtZqnHS94COQINeQ825TrKXxM5Fln0X9lK0-zHyeoaygczAYyY5IwMdGi1p27VDvrp6QUT1SUw',
#   'leaguePoints': 1391,
#   'rank': 'I',
#   'wins': 255,
#   'losses': 189,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'FCY2OSRaebNB1dR68P7Qr0L5AOxBP4DzzA_rK-TK1E2-U4yByLu_E-e2Mu3uNH-F2N4wb9AbUQa0Ig',
#   'leaguePoints': 1391,
#   'rank': 'I',
#   'wins': 110,
#   'losses': 80,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'puuid': 'jfpU24MyNszKbIke8XHDIuvuvBVcrlGIFsgT_HXV2wIpRNPWV2lAtPmAO9eLyHMkp0AzLJ9sRwdH1A',
#   'leaguePoints': 1382,
#   'rank': 'I',
#   'wins': 153,
#   'losses': 106,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': '2ZBz2l2NHnjSxif1eNi6E8RzfyUzYEbE32tzPmqwYaIRE8GjI1gW_cioNsvKCyVGz_w6fCHIPx3ojg',
#   'leaguePoints': 1379,
#   'rank': 'I',
#   'wins': 97,
#   'losses': 54,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'NhvS-HZYAEMGEn4NBctyQYrYznUlZ52pLYGtcAjyULWoXfu8Fc3S2dMzBJoTzR1r_ZodShJ-QwvVkQ',
#   'leaguePoints': 1375,
#   'rank': 'I',
#   'wins': 180,
#   'losses': 104,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'puuid': 'wCnhc0UTbJf2wERbeVqxT42AZmVWxOHzG-bKaCAeLHVl4hMehwivQHz76iPjUg519Dq8CUF0yKFMxA',
#   'leaguePoints': 1375,
#   'rank': 'I',
#   'wins': 147,
#   'losses': 117,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'qAN-1zZhnioI7mZzWg-zNEmNhY92E6rtvJQDHV7aStb4m7ggkWxDVg9oU7ndAs89H3nW93iU7Olusg',
#   'leaguePoints': 1370,
#   'rank': 'I',
#   'wins': 152,
#   'losses': 130,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'TO-_z-wMjxCMa08OVcLrNyJEv2FbdgmyFlj3E_KyleZDPgdNp2TvTAeo1jlykEzMUdbPO7_a0rSolw',
#   'leaguePoints': 1369,
#   'rank': 'I',
#   'wins': 194,
#   'losses': 128,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'Yx-S5fPNOwbJeYCcotZnCUzL6mbzhd03c4I1G9dgs_wTYuJmd0mWG2sg5xn8RkZNXQA64d6eKsmPaw',
#   'leaguePoints': 1362,
#   'rank': 'I',
#   'wins': 134,
#   'losses': 69,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'rDiXkGMT7JVsnfRtApVgo2Dd2AKhym-D8Na-BA7NV1uJLMAgHNEwS16Lz_EgzRvJz9B18RdFT6n9Qg',
#   'leaguePoints': 1361,
#   'rank': 'I',
#   'wins': 127,
#   'losses': 104,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'kgx4WXnq-dTIcY9p2figFu575UHtot7GdLyiEBdGrji2Ox-k4P80I6_mrA2vr5E5makgFI2KpJSJvA',
#   'leaguePoints': 1360,
#   'rank': 'I',
#   'wins': 131,
#   'losses': 94,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': '0nrz9yogoBnstpsLKhopyrsfiLWL51Yg6UXmPUYFa7v4mvtifzcaAfGKs05eQXYoPd_mPQuOGTB8Bg',
#   'leaguePoints': 1359,
#   'rank': 'I',
#   'wins': 168,
#   'losses': 119,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'p6NoYRim5zpRlrSRW7nDra1jvMkIG7GN5JhKHyENcFZGKrKUYLjQThU1caJw--kddhKo0YJurta6dg',
#   'leaguePoints': 1349,
#   'rank': 'I',
#   'wins': 183,
#   'losses': 128,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'K_FtQOU2qyEkzRKUkHrbHv6MxpQ2a6uu4YxMs6FqvCj5VWqewMYk8NqJcTmp5CHiyTxK5JFruMOj8g',
#   'leaguePoints': 1346,
#   'rank': 'I',
#   'wins': 117,
#   'losses': 76,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'Y43wTY23QS9qK1TimXnvruZYrDx2Av0GRNtnyk3s1UblshqaesKm13Rj2EWeRRU_-mXX47LfT3DOdw',
#   'leaguePoints': 1341,
#   'rank': 'I',
#   'wins': 282,
#   'losses': 212,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'puuid': 'lN3NHMmRP0Zu3Jh6uPgwGVOElV8rRNWMEj00h_BP39ISIhb38-VHyXpbPYRPqtN0WaSc8Lgylk_xkg',
#   'leaguePoints': 1327,
#   'rank': 'I',
#   'wins': 131,
#   'losses': 93,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'n8UKiEiS8lfXbXvcGVgEORwtUluOLVFi6egIF-paW5KgYZwdtznAXUOwrjXRy_ZaVGyxsyxdNGLxRQ',
#   'leaguePoints': 1315,
#   'rank': 'I',
#   'wins': 86,
#   'losses': 59,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'UliX4aXCq78Ov4q2l2rEU-9SWqXfXRyvHNY4RErUcmjOlKSr1iYDR_pUV_e6KTWTnKpb1s3tDC_IHQ',
#   'leaguePoints': 1302,
#   'rank': 'I',
#   'wins': 152,
#   'losses': 118,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'puuid': '1j3vO-86EWnoLioocU_E1I1wM6oJGA4gD_R_BB4FHevFNVIyscoa4xxzJbcvI3ZSE65qC7HiQvpojQ',
#   'leaguePoints': 1295,
#   'rank': 'I',
#   'wins': 117,
#   'losses': 69,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'puuid': 'FtDpZQbE_mLWDLyS6KGG9wx6yoZdNhjhA7t4LCzzqxo8gAjCeOrizonVm1em3MKkupTGHF6ApZgA2w',
#   'leaguePoints': 1293,
#   'rank': 'I',
#   'wins': 145,
#   'losses': 78,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': '13xgFSw5oSQ3pfn1OUz4QlSNUCW6lxtp7IzIbr2tVdiCJWXkVu2X7svAqDR8PmNNtN4HmjLdspSWSA',
#   'leaguePoints': 1290,
#   'rank': 'I',
#   'wins': 130,
#   'losses': 103,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'RuOzeSccdrnnguKytetjT9QYADCtOmox4lYk6v4of4mBl0bZ7IoJdr-qrpF69_jxiU15eQlt7xuA8w',
#   'leaguePoints': 1288,
#   'rank': 'I',
#   'wins': 205,
#   'losses': 144,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'Kn66r060LDhH67UVqJk5tcIYiGzR1nEUFBgBEnbB2ihwNyO3WNOZH1ZydERKnTNpLo0w7nqPsl5i3g',
#   'leaguePoints': 1285,
#   'rank': 'I',
#   'wins': 119,
#   'losses': 81,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'pQW28b3-maYLqeV5H4R-0_Qi2Fsm0x-A6-Ll-6TGJzgW2pJkr3RT2lKscH-2kfmUHkU5SBdhInYOzQ',
#   'leaguePoints': 1285,
#   'rank': 'I',
#   'wins': 97,
#   'losses': 37,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'g75lWCz9AF4MfmxoFnVTC9ZfwIjQxAPmAfFp_s-7rztsYEOExnPm_zphPPnzxiM0nbasKFr6OS1iew',
#   'leaguePoints': 1277,
#   'rank': 'I',
#   'wins': 183,
#   'losses': 107,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'puuid': 'QEYIhcu5y5jrH-JHsv5O_OztsKYQhj9QkeyyuBpDw-CN8fYLpR8_R4yg9PuTOJ7kyP2ex5U1CkBo1Q',
#   'leaguePoints': 1275,
#   'rank': 'I',
#   'wins': 102,
#   'losses': 60,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': '6Hr2nCc9R5yiapIyvol4R-W8DZJVqdCIs5qTh-tQCuc4P7KYEjOulq8faD_3tClNYVw873dZb47fcA',
#   'leaguePoints': 1274,
#   'rank': 'I',
#   'wins': 198,
#   'losses': 143,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'X4GKKiZbmajiLh2spKLx7jis28Fwn7s90Gj7d7b_MDQatqpb09bX_ATQA0cquVN2o8V2H0sByPhmZA',
#   'leaguePoints': 1273,
#   'rank': 'I',
#   'wins': 171,
#   'losses': 133,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'dRluI1bOmtKsUUW4ubgss85EK6p7dL5CPH-ID46Ik5tssJhmezNkcK1TqouZ142NoRhhu7xFgj659g',
#   'leaguePoints': 1272,
#   'rank': 'I',
#   'wins': 178,
#   'losses': 121,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'puuid': 'OPpx7VrlC_wGGBlXGgWPZGwlyIyEaJDfpEnQcoW1gjFyPVpM8t3ozrzzzuvqYjDVYNerJmvDKikXSw',
#   'leaguePoints': 1269,
#   'rank': 'I',
#   'wins': 168,
#   'losses': 108,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'IvF_XvOOju2v8iGB2d_vm33okjvCU2l7AA-2C4cOBS9oB_xL6JXBWmNk_-utO8I1wcyLrIira7SY8Q',
#   'leaguePoints': 1257,
#   'rank': 'I',
#   'wins': 113,
#   'losses': 50,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'lf-raZRdzhVmP9RFOK3YY_rNPvhyG3J4kWswI_ZCdHw0R0ChCmnjD1jfKIMlUf8hF7dgEE1IEJZakw',
#   'leaguePoints': 1256,
#   'rank': 'I',
#   'wins': 123,
#   'losses': 92,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'xe7rMApdZnKVEV6VUTNxRN7fQYveyVvIyzBO-wc3RdAJmVXNpjYW2Ya1Ur_2TTO9kW424iGs00E5FA',
#   'leaguePoints': 1255,
#   'rank': 'I',
#   'wins': 109,
#   'losses': 70,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'mPgK2C1gudmcXYXG9BhTusHKgHzEfr9HxoQJWUnsblp4bOBSJrHwAYsMh9zRud2laSzVk6hIuuLuhQ',
#   'leaguePoints': 1253,
#   'rank': 'I',
#   'wins': 156,
#   'losses': 127,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'puuid': 'Wklys_SeYI0eNItKERHCIoWXINQuf1cfG4eG4yenj2CjtF9b9HR9mKtBW9Y29QWAKCsfSTVr0DDY4A',
#   'leaguePoints': 1252,
#   'rank': 'I',
#   'wins': 154,
#   'losses': 126,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': '8gz5bcXtC2KuYWKsb1m0MdnOBmvS5b3aOaRndtbhjclIc-zaGmUmhyP-AmKLXXtgdZGnb6fcK1P0kw',
#   'leaguePoints': 1251,
#   'rank': 'I',
#   'wins': 106,
#   'losses': 83,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'puuid': 'Ytlxf36l-Fxj6yZ46YY-GWbgQsrltqZ-sGsrYLKnX2vjVU4kGjzmiHNcZgw-zceZUy8GyzhJQODT3Q',
#   'leaguePoints': 1245,
#   'rank': 'I',
#   'wins': 174,
#   'losses': 121,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'gxEksRwxE_NGHJ4QezIROIb-JmCMucMxuUa70zOlB3kPj3rxFr6PFOqRfajnVM2eAR1YGjrn75Cs3Q',
#   'leaguePoints': 1242,
#   'rank': 'I',
#   'wins': 140,
#   'losses': 108,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'MAUOYgxlGe0fk3UTPqI5fSGuzRq_-FicAlmVh0DFlWyLRMIKvNHvp8Hjj42eBUU_RYRKWggotSwPoQ',
#   'leaguePoints': 1238,
#   'rank': 'I',
#   'wins': 143,
#   'losses': 114,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'puuid': '4sN9-6LQosYxJUwLWmoNhRtzw4rdZuFsn0vg13Gkwz9wPzZas1Cag7C-gxTJmhCpVYhJZX5BKAuNjg',
#   'leaguePoints': 1236,
#   'rank': 'I',
#   'wins': 114,
#   'losses': 65,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'puuid': '_L3jG4Azuy4oi_Viwr5Kcohu_X7qTcD0Uqcp93VndPdBcCQQJrHAJhbzFWiqLbPDrkBEpCKz4MfuxQ',
#   'leaguePoints': 1231,
#   'rank': 'I',
#   'wins': 170,
#   'losses': 133,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'ExKvds6kLut3EuYbJ1QNeLsiahcyWq_w27FTcl2NK4F4d0NcOXghyTYPzqRK2JNR4DlFoA6u2OSvDg',
#   'leaguePoints': 1231,
#   'rank': 'I',
#   'wins': 152,
#   'losses': 120,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'khTi-n7slhAAH8IZP_XHNBYu3Jdsy-RjmyJxMOsH53-6IantqbDqA8UVutI2HL49zUTVUPrhVoRM7Q',
#   'leaguePoints': 1230,
#   'rank': 'I',
#   'wins': 107,
#   'losses': 61,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'wyOjHc5Z2d1eFn6F0jb-YLjLy5TFC8o13Cxkg0x-btCudwV1Vj3xs3sLqPAFONBJQw5odcHu4bMyjw',
#   'leaguePoints': 1224,
#   'rank': 'I',
#   'wins': 142,
#   'losses': 106,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'cJDU9sNJOIZxsjlErRV0j7eZowTNJ8pB6vZwvtYuP8CICBQv9o8gJdHDo0nHRaAr1GTRH_S22LdoJQ',
#   'leaguePoints': 1223,
#   'rank': 'I',
#   'wins': 123,
#   'losses': 96,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'puuid': 'HDjvqai0fVgXD5xBYc7JpBqKbhckVQB9hS0Q1N1WoGkifyP-V3EPKrYb3eS2_bRgzvFArChB-3uCaw',
#   'leaguePoints': 1220,
#   'rank': 'I',
#   'wins': 127,
#   'losses': 108,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'So-Kg76LQRfpQnZ_nHGa9yWXPM97wLjTnQerqvQ7XLtDQjhSiNTVobYnn0Y9iT17ZQhd-Q2_VrbxfA',
#   'leaguePoints': 1214,
#   'rank': 'I',
#   'wins': 102,
#   'losses': 77,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'IQpS2F-Vvyx1SD4oNAe4Ogc2mNYQv8SDzxhePc-iMVEwARC_H0tpoxhYBW8Oruo1Ix4-CJsivvX0dg',
#   'leaguePoints': 1213,
#   'rank': 'I',
#   'wins': 139,
#   'losses': 95,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'puuid': '9AycsmqLW5Ps4xF2TUrthxoDZNrCyvoo0HMIprPa8XRcMiurSPqTnLVnOj5aTRQTDmBTGVoTdBqjkg',
#   'leaguePoints': 1212,
#   'rank': 'I',
#   'wins': 151,
#   'losses': 129,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'pwZ9Z3Vr3_oKXHVzhh6VdZY6jAnmuh_ZutJ1s253JD4syjdejM2Z37R9f6gP5iRixu9nadMr7TBCxQ',
#   'leaguePoints': 1210,
#   'rank': 'I',
#   'wins': 131,
#   'losses': 99,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'X0_WEmdrxlqz7jzortV8RUPXOgn4zdyg-0wkP8N6SafrJ8EX6VsiXvdBRze3kHOGIhW8aXKT_qr_0Q',
#   'leaguePoints': 1204,
#   'rank': 'I',
#   'wins': 213,
#   'losses': 171,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'puuid': '8_Sli2IpMSlkcNbcr8bmjb6AIVgXn4Z3pX5BYA824BEGTLXIWazUbzYZE7vSEx1SphGAUWUHLsVmOA',
#   'leaguePoints': 1204,
#   'rank': 'I',
#   'wins': 164,
#   'losses': 140,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'IlrWeVIi_MLre7A8QocAzkNX0lZDRGWNqXCV6bzstpeUh56jSWkgEqFUqaCavpewvUnLJSeFzBAA9Q',
#   'leaguePoints': 1183,
#   'rank': 'I',
#   'wins': 112,
#   'losses': 71,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': '5tSgBh362mD-330cqUoFVODrUOcscA_F6ILiNbvFUp9PMLZWoyvK9Zb0BTy1lDW3ztZtv8RKvCaQIQ',
#   'leaguePoints': 1182,
#   'rank': 'I',
#   'wins': 110,
#   'losses': 51,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'HyDik0tquD8--v4jkqS-w9l5F4L8_DiyUy9YK9IIZmps2w05hBOMfDeVZEDj3roq4JxXPY9WECoSdQ',
#   'leaguePoints': 1179,
#   'rank': 'I',
#   'wins': 146,
#   'losses': 72,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'puuid': 'EE10M5JowN8vvvf5DYjSVpLfUNatb4cuS4nOXm5O9s03MjT98yxBqZESWdCXwDTX7XK4k4B5_H16mw',
#   'leaguePoints': 1177,
#   'rank': 'I',
#   'wins': 160,
#   'losses': 120,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'xLmtbNJ5_Ipuk-xcBfO9FaH30EpdprGExe24HrNpZlqb_WFkyqhhFDcqxMnc24XkeEIqundlYNxyTg',
#   'leaguePoints': 1176,
#   'rank': 'I',
#   'wins': 134,
#   'losses': 125,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'puuid': 'ic-3h0qnz_NJgdMBKQDGN-46fVDuBVf6tfKm7gh2NZSkuqIxrh1DpJMF_pSVg0U8w44u0b95AdwgHg',
#   'leaguePoints': 1174,
#   'rank': 'I',
#   'wins': 192,
#   'losses': 161,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': '_EKiOsF_uHJ5VUxVSwK3l314KNNq_aNYILffoCljv49fM4z2667dm-_kR4miJ4z98sTK69MkL3as5Q',
#   'leaguePoints': 1170,
#   'rank': 'I',
#   'wins': 130,
#   'losses': 100,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'puuid': 'L_3I2m6uZh6fpUFLH7S-7sdX_s3Lsqr-MZDvyFRB1YVozSOPTQyHDzze_4RIsn9fNolPMEKY8kf5SQ',
#   'leaguePoints': 1169,
#   'rank': 'I',
#   'wins': 107,
#   'losses': 40,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': '9n-ZbeHJooNruaxtdfq8wxVZ8Hk8kMEo_1J0-yPJxP6gv2cHRmOCXg3wwr65pl8jNFlMvYJfwiHtUw',
#   'leaguePoints': 1168,
#   'rank': 'I',
#   'wins': 192,
#   'losses': 151,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'puuid': 'yjQorUHjYb74vEPqbxX4EYpTpLF62otIanZN7OPSss6RMG_p8kDgV4uzyzXOm7oZvIF6MAYIZ_xeGw',
#   'leaguePoints': 1167,
#   'rank': 'I',
#   'wins': 145,
#   'losses': 129,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'ew5hch0HYK_n35OIcqFE3eySZD3sHvuMkf4R5g8ta16_eTKIL4Xq-ulF4IurQk_CeeQOj4sKwX9n-w',
#   'leaguePoints': 1158,
#   'rank': 'I',
#   'wins': 119,
#   'losses': 88,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'EdLUCour9ELeK4-GKt0rLeKWUNNboptaoIVcpda4ArgpIfJqydPDASSU7NeO5h-dobQfse97Q99xug',
#   'leaguePoints': 1157,
#   'rank': 'I',
#   'wins': 82,
#   'losses': 42,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'oERujVWqxWvXZciCrOunHbbdycwMzCYASU9qORHbaBPLjRu3qa_b0ctE9sm_w8SuBcNzj80nM3iM_A',
#   'leaguePoints': 1156,
#   'rank': 'I',
#   'wins': 182,
#   'losses': 159,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': '4nhz5yRrfnHJSXg38_Fj8syU7fVt1oy7izgrhR8RKEGXbneIQrFKQHwH2J-anqEu__ZP1Mny5SsyBg',
#   'leaguePoints': 1155,
#   'rank': 'I',
#   'wins': 179,
#   'losses': 149,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'xUKGE5801MvqLQUehjVfRZ3sHYAUI-50Yv4fQG7XHckV4F-uBAXmlA-A85-Q01pgDVuewpHKbTxgfw',
#   'leaguePoints': 1154,
#   'rank': 'I',
#   'wins': 97,
#   'losses': 51,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'puuid': 't4Daf-YIFB3MAKc1VayDxQxNePvI0odDEICGKlFx51uGNBsBzTPbyt_eGbz1F4TJtsY7m_7UOZ48Yw',
#   'leaguePoints': 1153,
#   'rank': 'I',
#   'wins': 106,
#   'losses': 61,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'puuid': 'OwOLiAl9PREpijr4sLk8PpMWev3uX5Si9WMkD3TQkEOby4LA6A9rF3kM5_mW-FC__qUfyGTd3jvzLw',
#   'leaguePoints': 1152,
#   'rank': 'I',
#   'wins': 132,
#   'losses': 91,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'puuid': 'v1HQ9LNfLWC8OhTBl0-FMgomHi8WvnaZUzaqMZp-m89RVlJHwvJ4uSQDv5Bm4firfXpU9ISQL2_1YQ',
#   'leaguePoints': 1148,
#   'rank': 'I',
#   'wins': 280,
#   'losses': 248,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'x-eEqhppLJeyoC0cW2kE4O2P29sRoQXNt1jeChG4r42Lo8bQ4zI4ct3gIB9NYX2vzSfWIJlHMZNdcg',
#   'leaguePoints': 1148,
#   'rank': 'I',
#   'wins': 249,
#   'losses': 218,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': '9drugiF1wKxOWP_5bz-qFh0IEMd_hdfK4k20th4N3XIIObQiO3IIub2AmbNGZUCgIJEy_C4YSNEMXw',
#   'leaguePoints': 1148,
#   'rank': 'I',
#   'wins': 79,
#   'losses': 33,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': '1Egjkh7P_LwELJ4toHSvkdnuqH9LhHn97kqkE_NlvQfMc4X4AAQ-asmLcJBMAFql0mgDoUrnKGl8vw',
#   'leaguePoints': 1146,
#   'rank': 'I',
#   'wins': 173,
#   'losses': 127,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'NATD1j-07O12fYfihmsP99PseRebBtOL_BRMu7rZTgpayq8HTmblReE2jK-Fr1INWdEeJuxFZhnkHQ',
#   'leaguePoints': 1146,
#   'rank': 'I',
#   'wins': 104,
#   'losses': 86,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': '7neZNKzwHqZlQgQdopV15hyF0vX0zQ7-Xvu_yAFl3MQxfiIUkt9iaSfOre5LNjq9Ci9i5vbYdEXQ9A',
#   'leaguePoints': 1141,
#   'rank': 'I',
#   'wins': 102,
#   'losses': 86,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'puuid': 'faGzuf78LEAO7uePIUszh2Ew6Gm1Rdk2to45Uk2zlDfdQa93cUp5H9Z9wa8PatM1aih0lFI8q0FvWw',
#   'leaguePoints': 1139,
#   'rank': 'I',
#   'wins': 104,
#   'losses': 81,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'Nju0ASTSyw7kyqJqP7J3vZWjxbiQ2jz2SIQ40xHzsMHjYw4FiNmC7xbiq6m7KQ-cT_p39zFqxycXvQ',
#   'leaguePoints': 1136,
#   'rank': 'I',
#   'wins': 104,
#   'losses': 47,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': '1XpDZ-ZfyZs80GfDihEnssLyaIGEHdSEzqpdJDUqW1UW50xWpilybTFlNO4H1NnJDrx6yd7TXColuw',
#   'leaguePoints': 1131,
#   'rank': 'I',
#   'wins': 203,
#   'losses': 168,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': '_BGg3KrIa67s1HqfRh2s_Zy4rK8CvBfhivmLHKhZQ3tpr15LYsKnI_SyqdYX5vfr3m05wNoPVfdOUQ',
#   'leaguePoints': 1131,
#   'rank': 'I',
#   'wins': 81,
#   'losses': 62,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': '8X-8x7wkNVsQSl5-f39voQgwizWjh42nuzdKVtWfAPIo7c2LZf_5gvGLnEERhLN12PJCLEprvQTyMw',
#   'leaguePoints': 1129,
#   'rank': 'I',
#   'wins': 253,
#   'losses': 197,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'IlZNB1NC-lIOyeKsyLvbJChAwPNAKrpc_7ZEg8t_t-u82OgopqyDvQ4dHdCCUJE5hVlY37X5MPFIgg',
#   'leaguePoints': 1127,
#   'rank': 'I',
#   'wins': 86,
#   'losses': 17,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'puuid': 'PQwEvs0TxJVX0skLC7UZknbUud-8Wg8hhxP5mE2mNUiHGhdGhlM_4qct1S-Byn1hN32ZKp9EbD6Uiw',
#   'leaguePoints': 1126,
#   'rank': 'I',
#   'wins': 118,
#   'losses': 96,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'puuid': 'Em5F9jfbmHZwsRL0-eoPIoEmSk-75YB6rkiE6mcNfoAlnqMyRBbkgMAVnzMTAeDKAwdwOheTtB-HKw',
#   'leaguePoints': 1126,
#   'rank': 'I',
#   'wins': 108,
#   'losses': 73,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'LlFu3gVXOPdPUdgOhyxwyrmxudRbf-wu3qlGMm-1iFYbdBGd5hAg4aOuMarceMxyyOqBR48pE0qG3A',
#   'leaguePoints': 1126,
#   'rank': 'I',
#   'wins': 94,
#   'losses': 51,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': '6Xt6dN3M0H5SNdkzeJ31wlguarSEyg2h_14tGyf1WjxkuG7qOd-KFQltuRkw5WTyGY6nVuUmjV395g',
#   'leaguePoints': 1125,
#   'rank': 'I',
#   'wins': 176,
#   'losses': 128,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'beC57hfHFKfIrVMcTzWWuu5Qw36zaiYgZsnDg8S8exCH-JKzJrQxZsXTTT8LeXNRKUF7W9lCkcbqqQ',
#   'leaguePoints': 1123,
#   'rank': 'I',
#   'wins': 104,
#   'losses': 89,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'uQXaskzIm_WA9B6_fZzNracW-EBRb2EGS59IQMKplyMb-mL3BLZKoPnxXA5shqe133R45THoTpNaUw',
#   'leaguePoints': 1118,
#   'rank': 'I',
#   'wins': 199,
#   'losses': 147,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'puuid': 'TGmx4SotOPjBMPEh459BoDUgJRGgY3hVDnn--FMEPS3QuyxIDoX37orgQb0CObFkr_EZPfssU7R_vw',
#   'leaguePoints': 1117,
#   'rank': 'I',
#   'wins': 74,
#   'losses': 45,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'FSCI0CX-pKSdc6xxiUEd-E-rgMxaSetB_wzMntin8jaEkb9eGMcGCnvi_irwXt-KIE-WIUgHc26YCQ',
#   'leaguePoints': 1115,
#   'rank': 'I',
#   'wins': 108,
#   'losses': 92,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'U2byYsw3moFsD7lLXZ5de-JTeOg4CbaSOeLo-fbBJb5MHS2TYoGdfOBN3QTYvs6y9P0zftX0Z1-0Cg',
#   'leaguePoints': 1111,
#   'rank': 'I',
#   'wins': 148,
#   'losses': 133,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': '3TFs_6XyVMVM5lrOnY-dkxHSq_Sr8OBM0FSIms_jF3xlqqPH4Il5s_x2euZRUucvboNAUDkInfdgPg',
#   'leaguePoints': 1110,
#   'rank': 'I',
#   'wins': 114,
#   'losses': 84,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': '_2MHqOt-IQ2u85iCS1BQpgszFm9JhAD9LdAmqhS95S5GVN03o6-2kbLWXbzgwTA0L_3lP7YDdgIByQ',
#   'leaguePoints': 1110,
#   'rank': 'I',
#   'wins': 90,
#   'losses': 54,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'puuid': 'pmsecoS5GsZ3VGN0YxPp21LwiEjeqk_xsSfQ4oK86l8ZFZrnQVrDwPJIzHYuaOYXlJgcADx1vW9bUQ',
#   'leaguePoints': 1102,
#   'rank': 'I',
#   'wins': 168,
#   'losses': 126,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'puuid': 'RZJFm5ryW30QSB-y3PwkoEyW7f8DMa9JEnVkQPFnEjMg3UhgyNZ1FrVLUDWhkZ-kvHBWvVcj5o4rAQ',
#   'leaguePoints': 1102,
#   'rank': 'I',
#   'wins': 97,
#   'losses': 71,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'puuid': 'hi5R3RdveMXOnZzY46wHt239TQdF4r8_lK4Ws52eH5CrwExM_524pjiD1N5bcrE-LQWrV_zEozvtbA',
#   'leaguePoints': 1100,
#   'rank': 'I',
#   'wins': 110,
#   'losses': 72,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'FeID3jQfXeL79DJvjHmSwIe5Cmwqy16X__hpuQVA5VVCupQuaNL7VAaN0UR1wY3vRejwf-mqGEqFRA',
#   'leaguePoints': 1099,
#   'rank': 'I',
#   'wins': 107,
#   'losses': 75,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'puuid': 'G_jS_5Z9akjQLD-EKpq4wZiItA56ah3hiIboZECDJCGzaA-zj17LN3InV8KQXJySx4uPIfgrzcmdIQ',
#   'leaguePoints': 1095,
#   'rank': 'I',
#   'wins': 109,
#   'losses': 66,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'puuid': 'yOMoBNvmWTsoMo5qn_m6XB4WACTntwHubklsF2LvkfPez7rqc5J-jYkRSM-dJiOEMDFOxL7lQKoRjQ',
#   'leaguePoints': 1093,
#   'rank': 'I',
#   'wins': 128,
#   'losses': 73,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'ri-PS409mzRKXm9JAtWePqrtEM_1WjHSAsU6k7B9_yfC-zpgm740spsN0nU9KXgQkKb-7UlBNJcisg',
#   'leaguePoints': 1093,
#   'rank': 'I',
#   'wins': 117,
#   'losses': 99,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'qRod_awUCK2nFYy5s6FJWoqkdxGR0o_VtbExL8fKGniI4LZ3cV8Kklfrr9iEjaZMcnQWdjoVTGsoDQ',
#   'leaguePoints': 1093,
#   'rank': 'I',
#   'wins': 106,
#   'losses': 86,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'puuid': 'X4lLDSSIwtUaJEgAaTlPCu02uoXb4yJGe3uQYeP05WvUiUZQMF0_UqAgAX42MXn8tJ3wzOuPOYfRaw',
#   'leaguePoints': 1090,
#   'rank': 'I',
#   'wins': 121,
#   'losses': 74,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'sMqmSYQ-EZz5ZBI_rY9j4rh7k6OpqYlkkXt-g1Sbupu2_l2vguOL6qjVjKW42mBV5jQ2pC4YfHtqvQ',
#   'leaguePoints': 1090,
#   'rank': 'I',
#   'wins': 79,
#   'losses': 53,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'puuid': '4mTMGuwzq8I2TT_MgtUKw_3DWAMkhBfjqT3kniHi67ooT_aXuok47ua2ZsleUPhs6b4upjkwKg6a3w',
#   'leaguePoints': 1087,
#   'rank': 'I',
#   'wins': 167,
#   'losses': 124,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'puuid': '8Qkgify6cXc3_xkZNFN-umZu5EuFFIOMKopxfa87I3k51JcAkAHnMZie_RL5z_gmPwl-UybBMg5JQg',
#   'leaguePoints': 1085,
#   'rank': 'I',
#   'wins': 127,
#   'losses': 109,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'LF95FLvNxIfrVglQIqNjgm4oa3weNUBO1ryO0xWYNaMU5Lobdcp-c0ehtvM37ULWn0yrSGYqw5vN-g',
#   'leaguePoints': 1085,
#   'rank': 'I',
#   'wins': 64,
#   'losses': 43,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'puuid': '0U66qIyqVwTI6TgQlQhsoz1fDfj4T0JtJnxRewxOHRubsj3pfWLAQIi1oZuel4DETU-Bk_gpLnSK5Q',
#   'leaguePoints': 1082,
#   'rank': 'I',
#   'wins': 84,
#   'losses': 42,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'YI51nBqhBgCOrKUVeWqP-ryjKh-A88Qtqf-r6gpT6YDfC1hbCKoBUfur2_Anuy4Av897iwBccGOK-Q',
#   'leaguePoints': 1080,
#   'rank': 'I',
#   'wins': 158,
#   'losses': 119,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'puuid': 'GXvvvrIYOYoNHGlUnVfyp-DZFg_TF5P9EXWn8gMdgqYToyFIhXSGwisjuTifHnDUBP7Ljt9HOe5EMg',
#   'leaguePoints': 1080,
#   'rank': 'I',
#   'wins': 151,
#   'losses': 102,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'puuid': 'wyWphlMy1YJmEHiy4cV2acPzpIuD9gRcnQ-5cVRY-riFbkMVAcEHgIRbG9VtUoApUCAR_u0WFkfwEA',
#   'leaguePoints': 1079,
#   'rank': 'I',
#   'wins': 84,
#   'losses': 66,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'TEbaLtKqVO8w___pHHjVgfLzP73WK9fc3z7kgTY4_3xHTOuNCY9D_z2SIyqx9unDj6dzAqCtp9bvMQ',
#   'leaguePoints': 1077,
#   'rank': 'I',
#   'wins': 74,
#   'losses': 26,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'kDqUIj8Owjqf32xwA492KsQhOiGgswA4Ab50sYCkJH0nxB3JwrNcRMB8Egt4H9A-ajI3vloOlSlL6g',
#   'leaguePoints': 1074,
#   'rank': 'I',
#   'wins': 91,
#   'losses': 71,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'WkUV47i2SCnppUkPU5eJcgP3kSak8dWmj0Lu-uYVVxHUFazITexBsY5agjXQAMmjRiBSGE9RRVkLOg',
#   'leaguePoints': 1073,
#   'rank': 'I',
#   'wins': 112,
#   'losses': 86,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'o8Ji5Y6yAIN1shORcy5toxKkjY6oHG2kdWeaf1JSU45pDJ8s1BW2kaIyxniKalzmEI9ff9tpVkrcPA',
#   'leaguePoints': 1072,
#   'rank': 'I',
#   'wins': 93,
#   'losses': 84,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'ynPGOP1a86fRC0PSrPPg95Hsb5v1xkHwpM_KUyufJdw0ZPguyCiI5-loeRKaAWY-s_vSiDnPqwUX4Q',
#   'leaguePoints': 1071,
#   'rank': 'I',
#   'wins': 113,
#   'losses': 82,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': '-18mWhRwfOKYp54GvZaXi8hr16xK6Ld3jH8IgRxH6vlAvEzR-At_NqxgoIHvBrpNR48AxIWT4Z8Fvg',
#   'leaguePoints': 1070,
#   'rank': 'I',
#   'wins': 109,
#   'losses': 75,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': '_QCri30M5E1aHni1kn_zkeS9CNDVnMwvaDxavFw4b13u9vyhcq3lXJseHmzmNf4pXEop8wqz540SMA',
#   'leaguePoints': 1070,
#   'rank': 'I',
#   'wins': 107,
#   'losses': 73,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'OM8XXJqhz4S4c3br6Nc5se9-xnALi-40EJRQPYP2uc-F25frZYayfuO9olUXW_TRgS6gq_nXc1VK0A',
#   'leaguePoints': 1070,
#   'rank': 'I',
#   'wins': 101,
#   'losses': 82,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'bOuGcABjWgZaD4Dkyya-_l2vU7b4mQ2IqY7-XWupn0XhFKAFIczqjLH1Gxg8ODQWQGgP-ZoEA4embg',
#   'leaguePoints': 1069,
#   'rank': 'I',
#   'wins': 142,
#   'losses': 116,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'p0a-NKwg5I1jrHJafRppl4v3B1DQCN1nq0lMtE9ApHLy4A9UU336U36PkOuAgx2xP-cUcycweiKRDg',
#   'leaguePoints': 1068,
#   'rank': 'I',
#   'wins': 154,
#   'losses': 119,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'puuid': 'ixOmvlGCOxq2LnpRefzLTTeixRSqz1lQx4-iTgfasI1FXopHwNPqpAc9JBx81xI4WilZL5MXITcueQ',
#   'leaguePoints': 1067,
#   'rank': 'I',
#   'wins': 90,
#   'losses': 59,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'puuid': '4IY3wH6ZcRuNc3Sh_toMLnXjTMRNteRmsAhWEhScILbS_I8voFbH0ohL3NW1R_PDn5KqcOFJZ0sKoQ',
#   'leaguePoints': 1065,
#   'rank': 'I',
#   'wins': 155,
#   'losses': 117,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'puuid': 'uR87KsPlXnf2nuUgB7lngP1VOGC5AdNPibRN5fkneiP6hu3gbSyVz4LabPxEL5o8K7JZv59krSe9ig',
#   'leaguePoints': 1064,
#   'rank': 'I',
#   'wins': 283,
#   'losses': 255,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'Ly1xbpy-GLzb4JboCV2_k0sZa-zRYMCu1WPhbKLVMPE1vqiVZNbkxSZAAYg1LQlm6MEPlLMXEdcafg',
#   'leaguePoints': 1060,
#   'rank': 'I',
#   'wins': 60,
#   'losses': 32,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'puuid': 'mFPn5R8zSzYG09B-wm_Azvfh37axLyRnhemkOKj_FbGcoQMS5S2hIIMFYCQ_febRKAyFakzw7XAx1w',
#   'leaguePoints': 1058,
#   'rank': 'I',
#   'wins': 105,
#   'losses': 92,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'puuid': 'HENQ_Fc1Iu-lPwHyDOs_YxlLIhR18uXp743kc3ZUmOhr23fC9OiYAyiT29TkQ0FWFH-k2w34vMUdbA',
#   'leaguePoints': 1056,
#   'rank': 'I',
#   'wins': 257,
#   'losses': 225,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'puuid': 'ZosWx4OGlMYLPPS3dm90550DfM_2g8QPghHXQXBp3X-_f97aXIlOvnc5audSsJbLKGhKhmvicPYZcw',
#   'leaguePoints': 1056,
#   'rank': 'I',
#   'wins': 214,
#   'losses': 183,
#   'veteran': True,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': '12D6xOjRiREn8XWxljOutV2QiwYn96uFi75ikLZxtx2_cvWZ7nPaFKi_Jy3ogMZI3GdoF-MiMBjmJw',
#   'leaguePoints': 1056,
#   'rank': 'I',
#   'wins': 103,
#   'losses': 89,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'puuid': 'H3rmue_Zrtm0qXwvwp1v7epKB02ZDx2Qs1gEMh0D_Go9HOq4KB_FtJ97Taw1zqr_Ljlsf3nR_K_zyw',
#   'leaguePoints': 1055,
#   'rank': 'I',
#   'wins': 108,
#   'losses': 55,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'puuid': 'cBpwO_T9pWAOsazAaWHjP7P4AdOigUmYL0nol1pT9g0EcZPVeW1k2ShhlejCP_aeRe1ktgkN8_EUBw',
#   'leaguePoints': 1055,
#   'rank': 'I',
#   'wins': 74,
#   'losses': 53,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'fSpiy1gkwL3dCLMrIx9a3HXwXewifAgEmH1rRD9j80OLAkNgGzyA3-AV__sbbU9-1LebOuT34FXA6w',
#   'leaguePoints': 1053,
#   'rank': 'I',
#   'wins': 171,
#   'losses': 136,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'puuid': 'lFGmCzPSdafL6gUvUYWJ2EPjTlobMjsvepom-EwOKNiBgCICh0B4EP1gPcbTkBmu9nEXfYIgjshdTQ',
#   'leaguePoints': 1053,
#   'rank': 'I',
#   'wins': 75,
#   'losses': 62,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'puuid': 'ptDkiwO9n4gLeiCEh6Wm-AkV-l0TTDuq0TVhS73mEY5KEl7hVy2OnWiXXVPEeWGXCqvxXI6PnlTuDA',
#   'leaguePoints': 1052,
#   'rank': 'I',
#   'wins': 223,
#   'losses': 174,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'puuid': '2Ol09t9AMt0azu0ekmFExnPeEnmZFJgJ0g9LYinZaC-afoyHkZR7ccDD6Z3l50HyVdRav_RixCTdUw',
#   'leaguePoints': 1052,
#   'rank': 'I',
#   'wins': 134,
#   'losses': 93,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'puuid': 'Bzb68l0ccC9SMjHJsOETqVyjtmY07GH3Kp0sWH7Cxto2P7EXosuE9MYDzPigowKS0JVWUBa5CmKk0w',
#   'leaguePoints': 1052,
#   'rank': 'I',
#   'wins': 96,
#   'losses': 73,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': '7KTOIsDTwgQZkM6aMnoPAtu0bpCjlpf3pWuBx9fksmvM7vlcUogms9HM_LT6Ptgr3v377aQdGyhTAA',
#   'leaguePoints': 1052,
#   'rank': 'I',
#   'wins': 87,
#   'losses': 69,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'puuid': 'tRlNf_4I4agLjx6kbHOJ9PIwEoqHhD4VRgV1zLVt3ideoNpTbWNulVO91TAlP5KDrF89SMSm9wlUug',
#   'leaguePoints': 1051,
#   'rank': 'I',
#   'wins': 111,
#   'losses': 82,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'OEU7Au1l6fboijwUT7YXw7mQZtPfV2LCWmS0DdcOkk7h-OgqZfzY-3UwEqTw3vRrAXKsOG9xOZgE_A',
#   'leaguePoints': 1050,
#   'rank': 'I',
#   'wins': 147,
#   'losses': 117,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': True},
#  {'puuid': '1fZwgrHN9WYs-MJwzRK9NsojXEcJsxILBnYLIC7UoBxY6Kahnc92kXgSvbdih7icBqmeK7sX0hWEGA',
#   'leaguePoints': 1050,
#   'rank': 'I',
#   'wins': 97,
#   'losses': 65,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'k5DGYTAEj6lfarckVDaXxrmtNzkN0ngjVz6C2uWFYuNyDb2KF43wWJRzmJgXBQ-jmuDUTZs_xCjUSg',
#   'leaguePoints': 1048,
#   'rank': 'I',
#   'wins': 122,
#   'losses': 97,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'Gs_RUy9L2FXMRErnAvwin6KydtGltpG5kV_Rq1g8u8S60mDFaFbg6FOb1PzUcPs00WJZb9GkVLIyTw',
#   'leaguePoints': 1048,
#   'rank': 'I',
#   'wins': 121,
#   'losses': 91,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'BUk8u2CuTt74g4YED6Wcbh8BcsEwhs2C8iAqtBRaTfaNhH_FMPXyNRJRXfzSNwSXheeUtx5lzngj5A',
#   'leaguePoints': 1047,
#   'rank': 'I',
#   'wins': 118,
#   'losses': 89,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'puuid': 'Labq-tQdDYMHgzrTCaY7qx-TkzqyCoDDGDA68RvnDl9DeMKdk9hSw8unU1jMoDX-w0A6AfHqLK_ieg',
#   'leaguePoints': 1044,
#   'rank': 'I',
#   'wins': 169,
#   'losses': 148,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'puuid': 'veOuH-bwcENT4S-O-PX1CpNrFFOgQIxq-RdJVDuPc6EGXOtFHnhvOS2WgzcvkAVBJuZVtbSUYYt1vA',
#   'leaguePoints': 1044,
#   'rank': 'I',
#   'wins': 127,
#   'losses': 90,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': '8km-HYiV5UScMLkOJIpOyDkVa-s3u7USTbMQACuMvx8DdKJui1CZUwr3hyMXIqr5TKGLBFOLU4tXEA',
#   'leaguePoints': 1043,
#   'rank': 'I',
#   'wins': 157,
#   'losses': 120,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'puuid': '8xKanYzxbPNN76-lcg2aL4Y8mR2m5UMnZEBZVCbQStzu83ceniizGyDwwPKlKZGF9yTdWTtpUw4uJQ',
#   'leaguePoints': 1042,
#   'rank': 'I',
#   'wins': 104,
#   'losses': 85,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'puuid': 'eivOFhMcPnGU07ppxTgQAWZ6rQQCcKs7eUT2MuS5e9sXtyPGGrh7-dUXpPdbNDc5ntf2e-IahivNLw',
#   'leaguePoints': 1041,
#   'rank': 'I',
#   'wins': 129,
#   'losses': 101,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'puuid': 'WygWvCUVkSDTOYkLZw6aO4v5qMMvnl1yo27UZoJpkJZhjGtE4gw0jBtbnd4SkUBXKhx9a_saqziPpA',
#   'leaguePoints': 1041,
#   'rank': 'I',
#   'wins': 89,
#   'losses': 42,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': True},
#  {'puuid': 'ZX475iJ7E2B4e6gUCvVk3_H5im08qGKYYLHpeNqqk04ghVZDII2XFa1YedsmJMlJIMGfREwKk_uXRQ',
#   'leaguePoints': 1040,
#   'rank': 'I',
#   'wins': 210,
#   'losses': 174,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'puuid': 'GyEVfxJqWGFUuM895VhxpCvn4mrw4ZJpKH-jdPseWnY0MEvF610EM7xoVn5MagiB8wTS3pTMerG1PA',
#   'leaguePoints': 1040,
#   'rank': 'I',
#   'wins': 133,
#   'losses': 104,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'r9hIcH1mGZdMOghhH1E2qNAdv9EzdCq70pi2zeBj8NNTuaebjC-D4lgtzypJcyHC3cAUbnBbgtsgmA',
#   'leaguePoints': 1040,
#   'rank': 'I',
#   'wins': 100,
#   'losses': 68,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'a24c1B7PjJFPKAZz2Y32Xzf6FzGavFaiz1MB7si68B-kJGl5kNoG-dKNGuPYpeNGyLgsqw6Xkux48A',
#   'leaguePoints': 1040,
#   'rank': 'I',
#   'wins': 77,
#   'losses': 50,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'uBK8Wbnh5z1WCGoB7k4wfvDiPiL4bvW_bHDvmsasipU8nVbSJPydEvuS4b4OfXa6vUAREF8WbmGxhg',
#   'leaguePoints': 1040,
#   'rank': 'I',
#   'wins': 71,
#   'losses': 48,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'puuid': 'SqCIpg5UAKUH3kAhZx4Ui1PfAdZusQSg27AKvp5kcYEEQUOI5HhtmOc6LHUqPnYBdbqDK_Ef4h9k7Q',
#   'leaguePoints': 1038,
#   'rank': 'I',
#   'wins': 211,
#   'losses': 167,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'puuid': 'Gf9Yfo2khZ3YXWLzevmCnmO470c_uz06zyIYASu9G90B6BUWwDFahe5w-y4kdfmE-uIo_LrHOLGNpw',
#   'leaguePoints': 1035,
#   'rank': 'I',
#   'wins': 117,
#   'losses': 84,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': True,
#   'hotStreak': False},
#  {'puuid': 'HRjk97Wh4qyCtb_fdDtSgYPz3HghCpuWg3JgyM6VkwF4THn0Ec2jiuaqQvpULgyCGPHC7S2wBlj0Ww',
#   'leaguePoints': 1033,
#   'rank': 'I',
#   'wins': 123,
#   'losses': 81,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False}]

# %% [markdown]
# Now to transform it into a DataFrame, to use this information, we can use the `pd.json_normalize` to the JSON data returned by the get request to turn it into a flat table.

# %%
api_ulr = 'https://br1.api.riotgames.com/lol/league/v4/challengerleagues/by-queue/RANKED_SOLO_5x5' + '?api_key='+ api_key
 
resp = requests.get(api_ulr)
challenger_summoners = pd.json_normalize(resp.json()['entries'])
challenger_summoners.head(3)
# Out:
#                                        summonerId    summonerName  \
# 0  cJS17ysl3L7wK6rvTybv93LQQIFfNXmzJTHyn6U7y44g_w         Atrasia
# 1  Qxhotb8LesY9wNI7iU2UlQQHMV7wLbODaFFWMvDWgjiluQ       Youngatti
# 2  -IaH1nm8elIFihOFSYPAowajun_zfpuU1pTudYfYv-pHYQ  ELOHIGH PUMITA
#
#    leaguePoints rank  wins  losses  veteran  inactive  freshBlood  hotStreak
# 0           996    I   249     168    False     False        True      False
# 1          1161    I   408     353     True     False       False      False
# 2          1004    I   193     147    False     False       False      False

# %% [markdown]
# Now that we now the basics about sending a request, getting the request data and transforming it into a DataFrame. We can join all we have done to create a funcion that will return all the information of players from Master to Challanger in Brazil, using the [League V4 Endpoint](https://developer.riotgames.com/apis#league-v4/GET_getMasterLeague).
#
# For this we will create a function that will take as a parameter the api_key.
#
# Now more about functions [here](https://www.programiz.com/python-programming/function)

# %%
def get_summonerId(api_key):
    challenger_url = 'https://br1.api.riotgames.com/lol/league/v4/challengerleagues/by-queue/RANKED_SOLO_5x5?api_key={}'.format(api_key) # Challanger ENDPOINT
    grandmaster_url = 'https://br1.api.riotgames.com/lol/league/v4/grandmasterleagues/by-queue/RANKED_SOLO_5x5?api_key={}'.format(api_key) # Grandmaster EDNPOINT
    master_url = 'https://br1.api.riotgames.com/lol/league/v4/masterleagues/by-queue/RANKED_SOLO_5x5?api_key={}'.format(api_key) # Master ENDPOINT

    league_url_lists = [challenger_url, grandmaster_url, master_url] # Creating a list with the 3 endpoints (master, grandmaster and challenger)

    df_list = [] # A list that will store the response from the get request (league_df)

    for url in league_url_lists: # Loop interation through league_url_lists
        resp = requests.get(url) # Sending a get request to the url
        league_df = pd.json_normalize(resp.json()['entries'])
        df_list.append(league_df)
    
    final_league_df = pd.concat(df_list) # Concatenating the stored information in league_url_lists to create the final_league_df

    return final_league_df

# %% [markdown]
# If we execute the function and assing it to a variable we can see the results

# %%
league_df = get_summonerId(api_key)
print('league_df has information about {} players between master and challenger elo'.format(league_df.shape[0]))
league_df.head(3)
# Out:
# league_df has information about 4574 players between master and challenger elo
#                                           summonerId   summonerName  \
# 0       h4bbmLl0hgcuN6OX4_xI2JVCkiCG14ONmR0MMQ3VtvLJ     SSG Corëjj
# 1  TwGS6c2Z3vsbdmmHOGH4LHgTOsbw1rZSboYSQ0qOPaUp9v...  não sou o sup
# 2     89g5w4-d6pXyPob_6PiAgJGlC2arZ-b5rr_VUnLlrWxcGQ     Kick a boo
#
#    leaguePoints rank  wins  losses  veteran  inactive  freshBlood  hotStreak
# 0          1192    I   316     257     True     False       False      False
# 1          1440    I   181     120     True     False       False      False
# 2          1265    I   359     294     True     False       False      False

# %% [markdown]
# Now that we have this information we can head to the Second part of this guide.

# %% [markdown]
# ### **PART II: [SUMMONER-V4 Endpoint](https://developer.riotgames.com/apis#summoner-v4/GET_getBySummonerId)**
#
# In this part we will use the `summonerId` column from the `league_df` that we have just created to retrieve the `puuid` and other information for each player, using the [SUMMONER-V4 Endpoint](https://developer.riotgames.com/apis#summoner-v4/GET_getBySummonerId).

# %% [markdown]
# Lets understand how this EDNPOINT works. [Click here](https://developer.riotgames.com/apis#summoner-v4) to go to the Summoner - V4 Endpoint.
#
# Click on the EDNPOINT "/lol/summoner/v4/summoners/{encryptedSummonerId}", scroll down and on the encryptedSummonerId value put one summonerId. Then click in "EXECUTE REQUEST".
#
# As we can see the Reponse Body contains summoners information, including the `puuid` that is what we want.
#
# Once again copy the request url in the code bellow
#
# The process will be very similar with your first api call, just a slight difference we won´t need to put ['entries'] to get the data, since the it is only a simple dictionary.

# %% [markdown]
# #### **Testing with one summonerId**

# %%
api_ulr = 'https://br1.api.riotgames.com/lol/summoner/v4/summoners/mx0nf-5HtF7GNZN7u_brogQVWKxSeabEQY4JNtfeiS9lmdQ' + '?api_key='+ api_key
 
resp = requests.get(api_ulr)
summoner_info = pd.json_normalize(resp.json())
summoner_info.head()
# Out:
#                                                 id  \
# 0  mx0nf-5HtF7GNZN7u_brogQVWKxSeabEQY4JNtfeiS9lmdQ
#
#                                            accountId  \
# 0  cr94iSRf_z9J4NzALZ335TO7Q2GMWMrO8Gu0RVw95ttdJ6...
#
#                                                puuid   name  profileIconId  \
# 0  -00t9W6o2B8dQYAEBHJoGifyJhObO-Kg14aTIOFMlQk9Xi...  Griba              7
#
#     revisionDate  summonerLevel
# 0  1666128939575            244

# %% [markdown]
# Now that we were able to retrieve the summoner_info for 1 player, we need to repeat this process for each summonerId in the league_df.
#
# To do that we will create another function that will receive a DataFram containing a column named "summonerId" (league_df) and the api_key. In this function we will create a for loop to iterate over each summonerId repeting the process we have just did above.

# %% [markdown]
# #### **Creating the function**

# %%
def get_summonerinfo_by_summonerId(df, api_key):
    
    summoner_list = [] # list that will store the each summoner_info DataFrame

    for i in range(len(df)): # len() get the numbers of rows of the match_ids parameter inserted. Then we use the range() function to create a sequence of number starting from 0 to number returned by len(). 
                            # With that we can interate trough each line in the match_ids dataframe (our function parameter) using the iloc function to get the matchid.

        # Creating a dynamic api_ulr for each register in the summonerId column using iloc
        api_url = ('https://br1.api.riotgames.com/lol/summoner/v4/summoners/{}?api_key={}'.format(df['summonerId'].iloc[i],api_key)

        # Repeating the process we did at the begining
        resp = requests.get(api_url)
        print(resp.status_code)

        # if, elif and while true to deal with riot api rate limit
        if resp.status_code == 200:
            pass
        elif resp.status_code == 429:
            while True: # while loop because of riot api cost
                if resp.status_code == 429: #429 error is api cost issue
                    print('429 delay try 10 second') #approximate 10 second wait before trying again
                    time.sleep(10)

                    # Trying again
                    api_url = ('https://br1.api.riotgames.com/lol/summoner/v4/summoners/{}?api_key={}'.format(df['summonerId'].iloc[i],api_key)
                    resp = requests.get(api_url)
                    print(resp.status_code)

                elif resp.status_code == 200:
                    print('limit cost resolve')
                    break

        summoner_info = pd.json_normalize(resp.json()) # The same process we did at the beggining to create the DataFrame
        summoner_list.append(summoner_info) # Appending the DataFrame generated (summoner_info) into the list "summoner_list"
        
    final_summoner_info = pd.concat(summoner_list) # Using pd.concat to concatenate the results stored in the list "summoner_list"
            
    return final_summoner_info

# %% [markdown]
# #### Executing the `'get_summonerinfo_by_summonerId'` function

# %% [markdown]
# If we execute the function and assing it to a variable we can see the results.
#
# Take care, because the code took about 1:30 hour to execute in my computer. So you might want to save it for further usage.

# %%
summoner_df = get_summonerinfo_by_summonerId(league_df, api_key)

# %% [markdown]
# Reseting the index

# %%
summoner_df.reset_index(inplace = True) # Reseting the Index
summoner_df.drop(columns='index', inplace = True) # Droping the column Index
summoner_df.head()

# %% [markdown]
# Saving the summoner_df

# %%
summoner_df.to_csv('summoner_df.csv', index = False)

# %% [markdown]
# ## **PART III: [MATCH-V5 Endpoint](https://developer.riotgames.com/apis#match-v5/GET_getMatch)**
#
# In this part we will use the `puuid` column from the `summoner_df`, that we've just created, to retrieve the last 20 matchIds for each `puuid`, using the [MATCH-V5 Endpoint](https://developer.riotgames.com/apis#match-v5/GET_getMatch).

# %% [markdown]
# So first lets understand how this EDNPOINT works. [Click here](https://developer.riotgames.com/apis#match-v5) to go to the Match-V5 Endpoint.
#
# Click on the EDNPOINT "/lol/match/v5/matches/by-puuid/{puuid}/ids", scroll down and on the path parameters insert this puuid "907TX3ji-JNb3NFS2m0hq0SBc4t0MFIuR0zG_nN-MAe1KY415e8GNgslVgdaBMXvfmFzLh5m7SvsiA". Now on the Query parameters insert '420' as the queue (you can check the queue Ids [here](https://github.com/Lacerdash/Extracting-League-of-Legends-data-with-Riot-Api/blob/main/Files/queues%20Id.xlsx) or [here](https://static.developer.riotgames.com/docs/lol/queues.json)) and select ranked as the type. After that you click in "EXECUTE REQUEST".
#
# As we can see in the Response Body contains a list of the last 20 match Ids from the player. So everything is all right.
#
# Once again get the request url and copy it in the api_url

# %% [markdown]
# #### **Testing with one puuid**

# %%
# & instead of ?, because there's already a ? in the original url
api_ulr = 'https://americas.api.riotgames.com/lol/match/v5/matches/by-puuid/907TX3ji-JNb3NFS2m0hq0SBc4t0MFIuR0zG_nN-MAe1KY415e8GNgslVgdaBMXvfmFzLh5m7SvsiA/ids?queue=420&type=ranked&start=0&count=20' + '&api_key=' + api_key
 
resp = requests.get(api_ulr)
resp.json()
# Out:
# ['BR1_2615782960',
#  'BR1_2615320466',
#  'BR1_2614740582',
#  'BR1_2614698761',
#  'BR1_2613549556',
#  'BR1_2613520962',
#  'BR1_2613508094',
#  'BR1_2613014340',
#  'BR1_2612988439',
#  'BR1_2612962248',
#  'BR1_2612915737',
#  'BR1_2612872659',
#  'BR1_2611353849',
#  'BR1_2610790841',
#  'BR1_2610780078',
#  'BR1_2610769542',
#  'BR1_2605729365',
#  'BR1_2605701933',
#  'BR1_2605689398',
#  'BR1_2605400824']

# %% [markdown]
# We can see that the data returned by `resp.json()` is a list of matchIds. To transform it into a DataFrame we can use pd.DataFrame(), passing the resp.json as the data and 'matchid' as the column.

# %%
api_ulr = 'https://americas.api.riotgames.com/lol/match/v5/matches/by-puuid/907TX3ji-JNb3NFS2m0hq0SBc4t0MFIuR0zG_nN-MAe1KY415e8GNgslVgdaBMXvfmFzLh5m7SvsiA/ids?queue=420&type=ranked&start=0&count=20' + '&api_key=' + api_key
 
resp = requests.get(api_ulr)
matchids = pd.DataFrame(resp.json(), columns = ['matchid'])
matchids.head(3)
# Out:
#           matchid
# 0  BR1_2614740582
# 1  BR1_2614698761
# 2  BR1_2613549556

# %% [markdown]
# Now that we were able to retrieve the last 20 5v5 Ranked Solo games for 1 player, we need to be able to repeat this process for each puuid in the summoner_df.
#
# To do that we will create a function that will receive a DataFrame containing a column named "puuid" (summoner_df) and the api_key. In this function we will create a for loop to iterate over each puuid repeting the process we have just did above.

# %% [markdown]
# #### **Creating the function**

# %%
def get_matchids_by_puuid(df, api_key):

    matchids_list = []

    for i in range(len(df)):

        api_url = 'https://americas.api.riotgames.com/lol/match/v5/matches/by-puuid/{}/ids?queue=420&type=ranked&start=0&count=20&api_key={}'.format(df['puuid'].iloc[i], api_key)

        resp = requests.get(api_url) # Sending a get request to the api_url
        print(resp.status_code)

        if resp.status_code == 200:
            pass
        elif resp.status_code == 429:
            while True: # while loop because of riot api cost
                if resp.status_code == 429: #429 error is api cost issue
                    print('429 delay try 100 second') #approximate 110 second wait
                    time.sleep(10)

                    api_url = 'https://americas.api.riotgames.com/lol/match/v5/matches/by-puuid/{}/ids?queue=420&type=ranked&start=0&count=20&api_key={}'.format(df['puuid'].iloc[i], api_key)
                    resp = requests.get(api_url)
                    print(resp.status_code)

                elif resp.status_code == 200:
                    print('limit cost resolve')
                    break        

        matchids = pd.DataFrame(resp.json(), columns = ['matchid']) 
        matchids_list.append(matchids) # Appending the DataFrame generated to the list "matchids_list"
    
    matchids_df = pd.concat(matchids_list) # Using pd.concat to concatenate the results stored in the "matchids_list"
    
    return matchids_df

# %% [markdown]
# #### **Executing the `get_matchids_by_puuid` function**
#
# Take care, because if you try to execute the function using the entire summoner_df it will took about 1:30 hours to execute, and it can fail many times before it runs successfully. So to avoida that, I’ve splited the summoner_df in half. Now I can run the function twice and then concatenated both results into a single DF. Each code takes about 45 minutes to complete, so you can do something while you are waiting. After that saved it for further usage.

# %%
print('O summoner_df possui {} linhas'.format(summoner_df.shape[0]))
# Out:
# O summoner_df possui 4399 linhas

# %%
matchids_df = get_matchids_by_puuid(summoner_df.loc[:2200], api_key)

# %%
matchids_df_1 = get_matchids_by_puuid(summoner_df.loc[2201:], api_key)

# %%
matchids_df_list = [matchids_df, matchids_df_1]

final_matchids_df= pd.concat(matchids_df_list)
final_matchids_df.head(3)
# Out:
#           matchid
# 0  BR1_2614740582
# 1  BR1_2614698761
# 2  BR1_2613549556

# %% [markdown]
# Reseting the Index

# %%
final_matchids_df.reset_index(inplace=True)
final_matchids_df.drop(columns = 'index', inplace = True )
final_matchids_df.head()

# %% [markdown]
# Dropping duplicates, since we only want unique matchids

# %%
final_matchids_df_without_duplicates = final_matchids_df.drop_duplicates()

# %%
matchids_count_before = final_matchids_df.shape[0]
matchids_count_after = final_matchids_df_without_duplicates.shape[0]
print('Before we had {} matchids, after we have {} matchids'.format(matchids_count_before, matchids_count_after))
# Out:
# Before we had 87980 matchids, after we have 35537 matchids

# %% [markdown]
# Saving the `matchids_df_without_duplicates`

# %%
final_matchids_df_without_duplicates.to_csv('matchids_df.csv', index = False)

# %% [markdown]
# ### **PART 4: [MATCH-V5 EDNPOINT](https://developer.riotgames.com/apis#match-v5/GET_getMatch)**
#
# In this part we will use the `matchid` column from the `matchids_df` to retrieve the match data for each `matchid`, using the [MATCH-V5 EDNPOINT](https://developer.riotgames.com/apis#match-v5/GET_getMatch).

# %%
# Importing the matchids_df.csv generated in the "PART 3: MATCH-V5 EDNPOINT" above
matchids_df = pd.read_csv('matchids_df.csv')
print('There is a total of {} matchIds in matchids_df.csv'.format(matchids_df.shape[0]))
# Out:
# There is a total of 35537 matchIds in matchids_df.csv

# %% [markdown]
# So first lets understand how this EDNPOINT works. [Click here](https://developer.riotgames.com/apis#match-v5) to go to the Match-V5 Endpoint.
#
# Click on the EDNPOINT "/lol/match/v5/matches/{matchId}" and scroll down. On the path parameters insert one matchid from the `matchids_df` and select SELECT the REGION you are working with, in my case is AMERICAS. Then click in "EXECUTE REQUEST".
#
# We can see in the Response Body the information retrieved.
#
# Now scroll up the page where you can see the request url. This is the url we are going to use to make our resquest in the code bellow.

# %% [markdown]
# #### **Testing with one match id**

# %% [markdown]
# Setting the api_ulr to make the get request

# %%
# The match id I used is the BR1_2583404284 inserted rigth before the "?api_key=", you can replace it with the one you have used.
api_ulr = 'https://americas.api.riotgames.com/lol/match/v5/matches/BR1_2583404284?api_key={}'.format(api_key)  
 
resp = requests.get(api_ulr)
resp.json()

# %% [markdown]
# There is a lot of data there, so we need to understand how the json file is structured so we can acess the data we want, which is the match data.
#
# [Here](https://developer.riotgames.com/apis#match-v5/GET_getMatch) you can find more information about the JSON file generated by this ENDPOINT.
#
# But basically it has two first keys: 'metadata' and 'info'. Lets explore each of these keys to understand what data is inside each one.

# %%
df = pd.json_normalize(resp.json()['metadata'])
df
# Out:
#   dataVersion         matchId  \
# 0           2  BR1_2583404284
#
#                                         participants
# 0  [tzx5O014rLZrM98l42XxZD9-N-cOXWqoi8FeMpOOP5KSM...

# %% [markdown]
# The `'metadata'` contains a list of puuid for every player in the game stored in the `'participants'` column.
#
# **IMPORTANT:** The order in which these puuid's appear in this the `'participants'` column list is the same order they will appear for data elsewhere in this dictionary.

# %%
df = pd.json_normalize(resp.json()['info'])
df
# Out:
#     gameCreation  gameDuration  gameEndTimestamp      gameId gameMode  \
# 0  1661728836215          2245     1661731199572  2583404284  CLASSIC
#
#                        gameName  gameStartTimestamp      gameType  \
# 0  teambuilder-match-2583404284       1661728954351  MATCHED_GAME
#
#       gameVersion  mapId                                       participants  \
# 0  12.16.462.4391     11  [{'assists': 6, 'baronKills': 0, 'basicPings':...
#
#   platformId  queueId                                              teams  \
# 0        BR1      440  [{'bans': [{'championId': 157, 'pickTurn': 1},...
#
#   tournamentCode
# 0

# %% [markdown]
# The `'info'` key has a lot of information about the match. But the main information is stored in the `'participants'` column. This column has a list, that contains a dictionary with kill, assist, deaths and other information for each player of the match.
#
# After said that, the information we want to get from the `'info'` key is the `'participants'` column.

# %%
# Getting the information inside the 'participants' columns
info_participant = pd.json_normalize(resp.json()['info']['participants'])
info_participant.head(10)
# Out:
#    assists  baronKills  basicPings  bountyLevel  champExperience  champLevel  \
# 0        6           0           2            0            21605          18
# 1        5           2          30            1            21097          18
# 2        4           0          22            0            19262          18
# 3        5           0           2            1            15151          16
# 4        9           0           3            0            14112          15
# 5        1           0          36            0            14629          15
# 6        7           0          25            1            16249          16
# 7        5           0          73            0            16582          17
# 8       15           0          10            0            13237          15
# 9        6           0          12            2            18840          18
#
#    championId championName  championTransform  consumablesPurchased  ...  \
# 0          77         Udyr                  0                     1  ...
# 1         121       Khazix                  0                    14  ...
# 2         268         Azir                  0                     6  ...
# 3         221         Zeri                  0                     1  ...
# 4          99          Lux                  0                     2  ...
# 5         126        Jayce                  0                     9  ...
# 6         102      Shyvana                  0                     1  ...
# 7          61      Orianna                  0                    12  ...
# 8         412       Thresh                  0                    13  ...
# 9          51      Caitlyn                  0                     3  ...
#
#    perks.statPerks.flex  perks.statPerks.offense  \
# 0                  5008                     5007
# 1                  5008                     5008
# 2                  5008                     5005
# 3                  5008                     5005
# 4                  5008                     5007
# 5                  5008                     5008
# 6                  5008                     5005
# 7                  5008                     5005
# 8                  5002                     5007
# 9                  5008                     5005
#
#                                         perks.styles  \
# 0  [{'description': 'primaryStyle', 'selections':...
# 1  [{'description': 'primaryStyle', 'selections':...
# 2  [{'description': 'primaryStyle', 'selections':...
# 3  [{'description': 'primaryStyle', 'selections':...
# 4  [{'description': 'primaryStyle', 'selections':...
# 5  [{'description': 'primaryStyle', 'selections':...
# 6  [{'description': 'primaryStyle', 'selections':...
# 7  [{'description': 'primaryStyle', 'selections':...
# 8  [{'description': 'primaryStyle', 'selections':...
# 9  [{'description': 'primaryStyle', 'selections':...
#
#    challenges.controlWardTimeCoverageInRiverOrEnemyHalf  \
# 0                                                NaN
# 1                                           0.589931
# 2                                           0.328858
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                           0.114875
# 7                                           0.068368
# 8                                           0.425645
# 9                                           0.061545
#
#    challenges.highestChampionDamage  challenges.highestWardKills  \
# 0                               NaN                          NaN
# 1                               1.0                          1.0
# 2                               NaN                          NaN
# 3                               NaN                          NaN
# 4                               NaN                          NaN
# 5                               NaN                          NaN
# 6                               NaN                          NaN
# 7                               NaN                          NaN
# 8                               NaN                          NaN
# 9                               NaN                          NaN
#
#    challenges.junglerKillsEarlyJungle  \
# 0                                 NaN
# 1                                 0.0
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# 5                                 NaN
# 6                                 0.0
# 7                                 NaN
# 8                                 NaN
# 9                                 NaN
#
#    challenges.killsOnLanersEarlyJungleAsJungler  \
# 0                                           NaN
# 1                                           1.0
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           0.0
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
#
#    challenges.fasterSupportQuestCompletion  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      1.0
# 9                                      NaN
#
#    challenges.highestCrowdControlScore
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# 5                                  NaN
# 6                                  NaN
# 7                                  NaN
# 8                                  1.0
# 9                                  NaN
#
# [10 rows x 232 columns]

# %% [markdown]
# As we can see we have data about all 10 players that played the match.

# %% [markdown]
# Now that we have understood how to use the RIOT EDNPOINTS to get a single match data. We are able to repeat this process for all the matchids stored in the matchid_df, merging in the end all the information in 1 DataFrame.
#
# To do that we will create a function that will take as a parameter a DF with a column named `'matchid'` containing the matchIds, and the api_key. In the end the final result will be a unique DataFrame with all the matches information.

# %%
def get_match_info_by_matchId(match_ids, api_key):

    matchid_info_list = [] # List that will store the dataframes generated, for each match id in the for loop 

    for i in range(len(match_ids)):# len() get the numbers of rows of the match_ids parameter inserted. Then we use the range() function to create a sequence of number starting from 0 to number returned by len(). 
                            # With that we can interate trough each line in the match_ids dataframe (our function parameter) using the iloc function to get the matchid.

        api_ulr = 'https://americas.api.riotgames.com/lol/match/v5/matches/{}?api_key={}'.format(match_ids['matchid'].iloc[i], api_key) # here we use the iloc function as explained above to form the api link for each matchid
        resp = requests.get(api_ulr) # Sending a get request to the api_url
        print(resp.status_code) # Printing the status_code of the request

        if resp.status_code == 200: # Here we need to use if statment, because of the riot API rate limit which is 20 requests every 1 sec and 100 requests every 2 minutes. A 200 status_code means that the request was successful so it can move on.
            pass                        
        elif resp.status_code == 429: # A 429 means that we have exceeded the rate limit. To solve that we need to wait and then try again to get a successful request
            while True: # To do taht we use a while true loop, to execute the if, elif statment repeatdly until the status_code is 200. After that we use break statement to come out of this loop.
                if resp.status_code == 429: 
                    print('429 delay try 10 second') #approximate 110 second wait to work
                    time.sleep(10) # Sleep

                    api_url = 'https://americas.api.riotgames.com/lol/match/v5/matches/{}?api_key={}'.format(match_ids['matchid'].iloc[i], api_key) # Trying the request again
                    resp = requests.get(api_url)
                    print(resp.status_code)

                elif resp.status_code == 200:
                    print('limit cost resolve')
                    break        

        # Same process we did in the beginning             
        matchid_info = pd.json_normalize(resp.json()['info']['participants'])
        matchid_info_list.append(matchid_info) # Merging all the dataframes generated and then stored in the matchid_info_list with the concat() function
        
    matchid_info_df = pd.concat(matchid_info_list)

    return matchid_info_df

# %% [markdown]
# #### **Execution the `'get_match_info_by_matchId'` function**

# %%
print('There is a total of {} matchIds in matchids_df.csv'.format(matchids_df.shape[0]))
# Out:
# There is a total of 35537 matchIds in matchids_df.csv

# %% [markdown]
# Since the DataFrame has 35.537 rows it would took a tremendous amount of time to loop trough it. Not only because of the rate limit, but also because, in many cases, when I tried to do all at once an unexpected error occured in the middle of the code and you simple lose all the information.
#
# So to avoid that I dicided to take a sample of 10.000 out of the `'matchids_df'`, which is a considerable amount, and separate it in 10 parts of 1.000 to make it easier to run the function all concatenate all together at the end.

# %%
# Dividing the sample DF
matchids_df_reduced = matchids_df.sample(10000, random_state = 57)

matchids_sample_1 = matchids_df_reduced.iloc[:1000]
matchids_sample_2 = matchids_df_reduced.iloc[1000:2000]
matchids_sample_3 = matchids_df_reduced.iloc[2000:3000]
matchids_sample_4 = matchids_df_reduced.iloc[3000:4000]
matchids_sample_5 = matchids_df_reduced.iloc[4000:5000]
matchids_sample_6 = matchids_df_reduced.iloc[5000:6000]
matchids_sample_7 = matchids_df_reduced.iloc[6000:7000]
matchids_sample_8 = matchids_df_reduced.iloc[7000:8000]
matchids_sample_9 = matchids_df_reduced.iloc[8000:9000]
matchids_sample_10 = matchids_df_reduced.iloc[9000:10000]

# %%
matchid_info_df_1 = get_match_info_by_matchId(matchids_sample_1, api_key)
matchid_info_df_1.to_csv('matchid_info_df_1.csv', index = False)

# %%
matchid_info_df_2 = get_match_info_by_matchId(matchids_sample_2, api_key)
matchid_info_df_2.to_csv('matchid_info_df_2.csv', index = False)

# %%
matchid_info_df_3 = get_match_info_by_matchId(matchids_sample_3, api_key)
matchid_info_df_3.to_csv('matchid_info_df_3.csv', index = False)

# %%
matchid_info_df_4 = get_match_info_by_matchId(matchids_sample_4, api_key)
matchid_info_df_4.to_csv('matchid_info_df_4.csv', index = False)

# %%
matchid_info_df_5 = get_match_info_by_matchId(matchids_sample_5, api_key)
matchid_info_df_5.to_csv('matchid_info_df_5.csv', index = False)

# %%
matchid_info_df_6 = get_match_info_by_matchId(matchids_sample_6, api_key)
matchid_info_df_6.to_csv('matchid_info_df_6.csv', index = False)

# %%
matchid_info_df_7 = get_match_info_by_matchId(matchids_sample_7, api_key)
matchid_info_df_7.to_csv('matchid_info_df_7.csv', index = False)

# %%
matchid_info_df_8 = get_match_info_by_matchId(matchids_sample_8, api_key)
matchid_info_df_8.to_csv('matchid_info_df_8.csv', index = False)

# %%
matchid_info_df_9 = get_match_info_by_matchId(matchids_sample_9, api_key)
matchid_info_df_9.to_csv('matchid_info_df_9.csv', index = False)

# %%
matchid_info_df_10 = get_match_info_by_matchId(matchids_sample_10, api_key)
matchid_info_df_10.to_csv('matchid_info_df_10.csv', index = False)

# %% [markdown]
# #### **Reading all the 10 DFs saved, to create 1 unique DF to store all the matches information**

# %%
matchid_info_df_list = []
for i in range(1, 11):
    df = pd.read_csv('matchid_info_df_{}.csv'.format(i))
    matchid_info_df_list.append(df)

matchData_df= pd.concat(matchid_info_df_list)
matchData_df
# Out:
#       assists  baronKills  basicPings  bountyLevel  champExperience  \
# 0          10           0        10.0            1            13643
# 1           7           1       100.0            3            14532
# 2          11           0        24.0            1            13207
# 3           7           0        13.0            3            12462
# 4          20           0        52.0            2            11338
# ...       ...         ...         ...          ...              ...
# 9995        0           0         7.0            0             4179
# 9996        3           0         2.0            0             3753
# 9997        0           0         0.0            5             6035
# 9998        1           0         1.0            0             3149
# 9999        2           0        18.0            0             2492
#
#       champLevel  championId championName  championTransform  \
# 0             15          79       Gragas                  0
# 1             15         131        Diana                  0
# 2             15         157        Yasuo                  0
# 3             14         145        Kaisa                  0
# 4             13         526         Rell                  0
# ...          ...         ...          ...                ...
# 9995           8          27       Singed                  0
# 9996           7          35        Shaco                  0
# 9997           9         157        Yasuo                  0
# 9998           6          15        Sivir                  0
# 9999           6         888       Renata                  0
#
#       consumablesPurchased  ...  challenges.soloTurretsLategame  \
# 0                        3  ...                             NaN
# 1                        5  ...                             NaN
# 2                        2  ...                             NaN
# 3                        3  ...                             NaN
# 4                       19  ...                             NaN
# ...                    ...  ...                             ...
# 9995                     0  ...                             NaN
# 9996                     2  ...                             NaN
# 9997                     3  ...                             NaN
# 9998                     2  ...                             NaN
# 9999                     5  ...                             NaN
#
#       challenges.highestCrowdControlScore  challenges.highestWardKills  \
# 0                                     NaN                          NaN
# 1                                     NaN                          NaN
# 2                                     NaN                          NaN
# 3                                     NaN                          NaN
# 4                                     NaN                          NaN
# ...                                   ...                          ...
# 9995                                  NaN                          NaN
# 9996                                  NaN                          NaN
# 9997                                  NaN                          NaN
# 9998                                  NaN                          NaN
# 9999                                  1.0                          1.0
#
#       challenges.hadAfkTeammate  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 9995                        NaN
# 9996                        NaN
# 9997                        NaN
# 9998                        NaN
# 9999                        NaN
#
#       challenges.shortestTimeToAceFromFirstTakedown  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 9995                                            NaN
# 9996                                            NaN
# 9997                                            NaN
# 9998                                            NaN
# 9999                                            NaN
#
#       challenges.baronBuffGoldAdvantageOverThreshold  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 9995                                             NaN
# 9996                                             NaN
# 9997                                             NaN
# 9998                                             NaN
# 9999                                             NaN
#
#       challenges.fasterSupportQuestCompletion  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 9995                                      NaN
# 9996                                      NaN
# 9997                                      NaN
# 9998                                      NaN
# 9999                                      NaN
#
#       challenges.thirdInhibitorDestroyedTime  challenges.earliestElderDragon  \
# 0                                        NaN                             NaN
# 1                                        NaN                             NaN
# 2                                        NaN                             NaN
# 3                                        NaN                             NaN
# 4                                        NaN                             NaN
# ...                                      ...                             ...
# 9995                                     NaN                             NaN
# 9996                                     NaN                             NaN
# 9997                                     NaN                             NaN
# 9998                                     NaN                             NaN
# 9999                                     NaN                             NaN
#
#       challenges.mejaisFullStackInTime
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 9995                               NaN
# 9996                               NaN
# 9997                               NaN
# 9998                               NaN
# 9999                               NaN
#
# [99990 rows x 238 columns]

# %% [markdown]
# Saving the `'matchData_df'`

# %%
matchData_df.to_csv('matchData_df.csv', index = False)

# %% [markdown]
# ### **Next steps?**
#
# With that, we've concluded our guide to the Riot API: Extracting League of Legends Match Data
#
# Now you have created your own DataBase. So you can use that to make exploratory analysis to crate hypothesis. In additional to that, you can make some data visualization using python or other program.
#
# This guide was 1 of many usage cases for the Riot API. To help you think of potential ideas, I'll list a few of the popular APIs that you can use:
#
# - How much Mastery a player has on each Champion
# - In-depth game detail for every minute of the game (i.e. how much Gold/XP each player has at 12 minutes)
# - In-depth objective and kill data, like who killed who, when and where
# - Ranked information, such as their current rank for each queue
# - Who is currently in Challenger, Grand Master & Master (& every queue below that too!)
# - And much more...!
#
# You can connect with me in likedin to ask questions: https://www.linkedin.com/in/fernando-lacerda-/
#
# I'am starting to write a articles about statistics/AI/esports/gaming, you can subscribe here:

# %% [markdown]
# I listed bellow the main columns from the matchData_df, so you do not have to worry about figuring out which column to use. If you want to know more about the columns I can check that in the [MATCH-V5 EDNPOINT](https://developer.riotgames.com/apis#match-v5/GET_getMatch)

# %%
useful_columns = ['assists', 'champLevel', 'championName', 'deaths', 'detectorWardsPlaced', 'gameEndedInEarlySurrender', 
                'gameEndedInSurrender', 'goldEarned', 'inhibitorsLost', 'kills', 'magicDamageDealt', 'magicDamageDealtToChampions', 
                'neutralMinionsKilled', 'physicalDamageDealt', 'physicalDamageDealtToChampions', 'physicalDamageTaken', 'profileIcon', 
                'sightWardsBoughtInGame', 'teamId', 'teamPosition', 'totalDamageDealt', 'totalDamageDealtToChampions', 'totalMinionsKilled', 
                'trueDamageDealt', 'trueDamageDealtToChampions', 'turretsLost', 'visionScore', 'wardsKilled', 'wardsPlaced', 'win'
                ]

print('The original dataset has {}, I choose to use {} columns'.format(matchData_df.shape[1], len(useful_columns)))
# Out:
# The original dataset has 238, I choose to use 30 columns
